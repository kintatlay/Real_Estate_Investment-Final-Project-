# %%
# Dependencies
from bs4 import BeautifulSoup
import requests

# %%
linked = 'https://www.century21.com/real-estate/california/LSCA/'

response = requests.get(linked)
soup = BeautifulSoup(response.text, 'html.parser')
result = soup.find_all('div', class_="property-card-primary-info")
result
# Out:
# [<div class="property-card-primary-info">
#  <div class="pdp-listing-type sale">FOR SALE</div>
#  <a class="listing-price" href="/property/340-juanita-avenue-oceano-ca-93445-C2180900687">
#
#
#                 $949,500
#
#
#
#        </a>
#  <div class="col-wrap-mid">
#  <div class="property-beds">
#  <strong>4</strong> beds
#           </div>
#  <div class="property-baths">
#  <strong>3</strong> baths
#           </div>
#  </div>
#  <div class="col-wrap-last">
#  <div class="property-half-baths">
#  <strong>1</strong> half bath
#           </div>
#  <div class="property-sqft">
#  <strong>2,166</strong> sq. ft
#           </div>
#  </div>
#  <div class="property-address-info">
#  <div class="property-address" title="340 Juanita Avenue">
#                 340 Juanita Avenue
#              </div>
#  <div class="property-city">
#              Oceano CA 93445
#           </div>
#  </div>
#  <div class="property-card-attribution">
#                 Listed By CENTURY 21 Hometown Realty
#
#           </div>
#  </div>, <div class="property-card-primary-info">
#  <div class="pdp-listing-type sale">FOR SALE</div>
#  <a class="listing-price" href="/property/241-american-river-canyon-dr-folsom-ca-95630-C2180900484">
#
#
#                 $929,900
#
#
#
#        </a>
#  <div class="col-wrap-mid">
#  <div class="property-beds">
#  <strong>5</strong> beds
#           </div>
#  <div class="property-baths">
#  <strong>3</strong> baths
#           </div>
#  </div>
#  <div class="col-wrap-last">
#  <div class="property-half-baths">
#  <strong>1</strong> half bath
#           </div>
#  <div class="property-sqft">
#  <strong>4,185</strong> sq. ft
#           </div>
#  </div>
#  <div class="property-address-info">
#  <div class="property-address" title="241 American River Canyon Dr">
#                 241 American River Canyon Dr
#              </div>
#  <div class="property-city">
#              Folsom CA 95630
#           </div>
#  </div>
#  <div class="property-card-attribution">
#                 Listed By CENTURY 21 MM
#
#           </div>
#  </div>, <div class="property-card-primary-info">
#  <div class="pdp-listing-type sale">FOR SALE</div>
#  <a class="listing-price" href="/property/3634-7th-ave-3e-san-diego-ca-92103-C2180900534">
#
#
#                 $649,000
#
#
#
#        </a>
#  <div class="col-wrap-mid">
#  <div class="property-beds">
#  <strong>3</strong> beds
#           </div>
#  <div class="property-baths">
#  <strong>2</strong> baths
#           </div>
#  </div>
#  <div class="col-wrap-last">
#  <div class="property-sqft">
#  <strong>1,517</strong> sq. ft
#           </div>
#  </div>
#  <div class="property-address-info">
#  <div class="property-address" title="3634 7th Ave 3E">
#                 3634 7th Ave 3E
#              </div>
#  <div class="property-city">
#              San Diego CA 92103
#           </div>
#  </div>
#  <div class="property-card-attribution">
#                 Listed By CENTURY 21 Award
#
#           </div>
#  </div>, <div class="property-card-primary-info">
#  <div class="pdp-listing-type sale">FOR SALE</div>
#  <a class="listing-price" href="/property/1033-eclipse-way-west-covina-ca-91792-C2180900669">
#
#
#                 $570,000
#
#
#
#        </a>
#  <div class="col-wrap-mid">
#  <div class="property-beds">
#  <strong>4</strong> beds
#           </div>
#  <div class="property-baths">
#  <strong>2</strong> baths
#           </div>
#  </div>
#  <div class="col-wrap-last">
#  <div class="property-sqft">
#  <strong>1,394</strong> sq. ft
#           </div>
#  </div>
#  <div class="property-address-info">
#  <div class="property-address" title="1033 Eclipse Way">
#                 1033 Eclipse Way
#              </div>
#  <div class="property-city">
#              West Covina CA 91792
#           </div>
#  </div>
#  <div class="property-card-attribution">
#                 Listed By CENTURY 21 Marty Rodriguez
#
#           </div>
#  </div>, <div class="property-card-primary-info">
#  <div class="pdp-listing-type sale">FOR SALE</div>
#  <a class="listing-price" href="/property/984-glendora-ave-35-glendora-ca-91740-C2180900777">
#
#
#                 $539,999
#
#
#
#        </a>
#  <div class="col-wrap-mid">
#  <div class="property-beds">
#  <strong>3</strong> beds
#           </div>
#  <div class="property-baths">
#  <strong>3</strong> baths
#           </div>
#  </div>
#  <div class="col-wrap-last">
#  <div class="property-sqft">
#  <strong>1,860</strong> sq. ft
#           </div>
#  </div>
#  <div class="property-address-info">
#  <div class="property-address" title="984 Glendora Ave. # 35">
#                 984 Glendora Ave. # 35
#              </div>
#  <div class="property-city">
#              Glendora CA 91740
#           </div>
#  </div>
#  <div class="property-card-attribution">
#                 Listed By CENTURY 21 King
#
#           </div>
#  </div>, <div class="property-card-primary-info">
#  <div class="pdp-listing-type sale">FOR SALE</div>
#  <a class="listing-price" href="/property/23204-cresta-twain-harte-ca-95383-C2180900443">
#
#
#                 $300,000
#
#
#
#        </a>
#  <div class="col-wrap-mid">
#  <div class="property-beds">
#  <strong>3</strong> beds
#           </div>
#  <div class="property-baths">
#  <strong>1</strong> bath
#           </div>
#  </div>
#  <div class="col-wrap-last">
#  <div class="property-half-baths">
#  <strong>1</strong> half bath
#           </div>
#  <div class="property-sqft">
#  <strong>1,182</strong> sq. ft
#           </div>
#  </div>
#  <div class="property-address-info">
#  <div class="property-address" title="23204 Cresta">
#                 23204 Cresta
#              </div>
#  <div class="property-city">
#              Twain Harte CA 95383
#           </div>
#  </div>
#  <div class="property-card-attribution">
#                 Listed By CENTURY 21 Wildwood Properties, Inc.
#
#           </div>
#  </div>, <div class="property-card-primary-info">
#  <div class="pdp-listing-type sale">FOR SALE</div>
#  <a class="listing-price" href="/property/3410-w-mesa-fresno-ca-93711-C2180900788">
#
#
#                 $223,000
#
#
#
#        </a>
#  <div class="col-wrap-mid">
#  <div class="property-beds">
#  <strong>3</strong> beds
#           </div>
#  <div class="property-baths">
#  <strong>1</strong> bath
#           </div>
#  </div>
#  <div class="col-wrap-last">
#  <div class="property-half-baths">
#  <strong>1</strong> half bath
#           </div>
#  <div class="property-sqft">
#  <strong>1,100</strong> sq. ft
#           </div>
#  </div>
#  <div class="property-address-info">
#  <div class="property-address" title="3410 W Mesa">
#                 3410 W Mesa
#              </div>
#  <div class="property-city">
#              Fresno CA 93711
#           </div>
#  </div>
#  <div class="property-card-attribution">
#                 Listed By CENTURY 21 Adanalian &amp; Vasquez Real Estate
#
#           </div>
#  </div>, <div class="property-card-primary-info">
#  <div class="pdp-listing-type sale">FOR SALE</div>
#  <a class="listing-price" href="/property/555-4th-street-unit-106-san-francisco-ca-94107-REN003792804">
#
#
#                 $1,795,000
#
#
#
#        </a>
#  <div class="col-wrap-mid">
#  <div class="property-beds">
#  <strong>3</strong> beds
#           </div>
#  <div class="property-baths">
#  <strong>3</strong> baths
#           </div>
#  </div>
#  <div class="col-wrap-last">
#  </div>
#  <div class="property-address-info">
#  <div class="property-address" title="555 4th Street Unit: 106">
#                 555 4th Street Unit: 106
#              </div>
#  <div class="property-city">
#              San Francisco CA 94107
#           </div>
#  </div>
#  <div class="property-card-attribution">
#                 Courtesy Of Climb Real Estate
#
#           </div>
#  </div>, <div class="property-card-primary-info">
#  <div class="pdp-listing-type sale">FOR SALE</div>
#  <a class="listing-price" href="/property/495-ridgecrest-cir-livermore-ca-94551-REN003792081">
#
#
#                 $948,888
#
#
#
#        </a>
#  <div class="col-wrap-mid">
#  <div class="property-beds">
#  <strong>3</strong> beds
#           </div>
#  <div class="property-baths">
#  <strong>2</strong> baths
#           </div>
#  </div>
#  <div class="col-wrap-last">
#  <div class="property-half-baths">
#  <strong>1</strong> half bath
#           </div>
#  <div class="property-sqft">
#  <strong>1,966</strong> sq. ft
#           </div>
#  </div>
#  <div class="property-address-info">
#  <div class="property-address" title="495 Ridgecrest Cir">
#                 495 Ridgecrest Cir
#              </div>
#  <div class="property-city">
#              Livermore CA 94551
#           </div>
#  </div>
#  <div class="property-card-attribution">
#                 Courtesy Of Intero Real Estate Services
#
#           </div>
#  </div>, <div class="property-card-primary-info">
#  <div class="pdp-listing-type sale">FOR SALE</div>
#  <a class="listing-price" href="/property/2342-lakeview-dr-san-leandro-ca-94577-REN003792103">
#
#
#                 $799,000
#
#
#
#        </a>
#  <div class="col-wrap-mid">
#  <div class="property-beds">
#  <strong>3</strong> beds
#           </div>
#  <div class="property-baths">
#  <strong>2</strong> baths
#           </div>
#  </div>
#  <div class="col-wrap-last">
#  <div class="property-sqft">
#  <strong>1,834</strong> sq. ft
#           </div>
#  </div>
#  <div class="property-address-info">
#  <div class="property-address" title="2342 Lakeview Dr">
#                 2342 Lakeview Dr
#              </div>
#  <div class="property-city">
#              San Leandro CA 94577
#           </div>
#  </div>
#  <div class="property-card-attribution">
#                 Courtesy Of Daniel Winkler &amp; Associates, Inc.
#
#           </div>
#  </div>, <div class="property-card-primary-info">
#  <div class="pdp-listing-type sale">FOR SALE</div>
#  <a class="listing-price" href="/property/528-webster-dr-martinez-ca-94553-REN003792109">
#
#
#                 $750,000
#
#
#
#        </a>
#  <div class="col-wrap-mid">
#  <div class="property-beds">
#  <strong>4</strong> beds
#           </div>
#  <div class="property-baths">
#  <strong>2</strong> baths
#           </div>
#  </div>
#  <div class="col-wrap-last">
#  <div class="property-sqft">
#  <strong>1,430</strong> sq. ft
#           </div>
#  </div>
#  <div class="property-address-info">
#  <div class="property-address" title="528 Webster Dr">
#                 528 Webster Dr
#              </div>
#  <div class="property-city">
#              Martinez CA 94553
#           </div>
#  </div>
#  <div class="property-card-attribution">
#                 Courtesy Of Keller Williams Realty
#
#           </div>
#  </div>, <div class="property-card-primary-info">
#  <div class="pdp-listing-type sale">FOR SALE</div>
#  <a class="listing-price" href="/property/1553-shelter-lane-murphys-ca-95247-REN003503831">
#
#
#                 $700,000
#
#
#
#        </a>
#  <div class="col-wrap-mid">
#  <div class="property-beds">
#  <strong>3</strong> beds
#           </div>
#  <div class="property-baths">
#  <strong>2</strong> baths
#           </div>
#  </div>
#  <div class="col-wrap-last">
#  <div class="property-half-baths">
#  <strong>1</strong> half bath
#           </div>
#  <div class="property-sqft">
#  <strong>3,242</strong> sq. ft
#           </div>
#  </div>
#  <div class="property-address-info">
#  <div class="property-address" title="1553 Shelter Lane">
#                 1553 Shelter Lane
#              </div>
#  <div class="property-city">
#              Murphys CA 95247
#           </div>
#  </div>
#  <div class="property-card-attribution">
#                 Courtesy Of Barry Ward Realty
#
#           </div>
#  </div>, <div class="property-card-primary-info">
#  <div class="pdp-listing-type sale">FOR SALE</div>
#  <a class="listing-price" href="/property/6306-caminito-estrellado-san-diego-ca-92120-REN003791901">
#
#
#                 $699,000
#
#
#
#        </a>
#  <div class="col-wrap-mid">
#  <div class="property-beds">
#  <strong>3</strong> beds
#           </div>
#  <div class="property-baths">
#  <strong>2</strong> baths
#           </div>
#  </div>
#  <div class="col-wrap-last">
#  <div class="property-half-baths">
#  <strong>1</strong> half bath
#           </div>
#  <div class="property-sqft">
#  <strong>2,078</strong> sq. ft
#           </div>
#  </div>
#  <div class="property-address-info">
#  <div class="property-address" title="6306 Caminito Estrellado">
#                 6306 Caminito Estrellado
#              </div>
#  <div class="property-city">
#              San Diego CA 92120
#           </div>
#  </div>
#  <div class="property-card-attribution">
#                 Courtesy Of Hill &amp; Hill Realty, Inc.
#
#           </div>
#  </div>, <div class="property-card-primary-info">
#  <div class="pdp-listing-type sale">FOR SALE</div>
#  <a class="listing-price" href="/property/30-hampton-ct-oakley-ca-94561-REN003792094">
#
#
#                 $525,000
#
#
#
#        </a>
#  <div class="col-wrap-mid">
#  <div class="property-beds">
#  <strong>3</strong> beds
#           </div>
#  <div class="property-baths">
#  <strong>2</strong> baths
#           </div>
#  </div>
#  <div class="col-wrap-last">
#  <div class="property-sqft">
#  <strong>1,975</strong> sq. ft
#           </div>
#  </div>
#  <div class="property-address-info">
#  <div class="property-address" title="30 Hampton Ct">
#                 30 Hampton Ct
#              </div>
#  <div class="property-city">
#              Oakley CA 94561
#           </div>
#  </div>
#  <div class="property-card-attribution">
#                 Courtesy Of Keller Williams East County
#
#           </div>
#  </div>, <div class="property-card-primary-info">
#  <div class="pdp-listing-type sale">FOR SALE</div>
#  <a class="listing-price" href="/property/1591-lindacrest-dr-beverly-hills-ca-90210-C2180900624">
#
#
#                 $2,495,000
#
#
#
#        </a>
#  <div class="col-wrap-mid">
#  <div class="property-beds">
#  <strong>3</strong> beds
#           </div>
#  <div class="property-baths">
#  <strong>3</strong> baths
#           </div>
#  </div>
#  <div class="col-wrap-last">
#  <div class="property-sqft">
#  <strong>3,010</strong> sq. ft
#           </div>
#  </div>
#  <div class="property-address-info">
#  <div class="property-address" title="1591 Lindacrest Dr">
#                 1591 Lindacrest Dr
#              </div>
#  <div class="property-city">
#              Beverly Hills CA 90210
#           </div>
#  </div>
#  <div class="property-card-attribution">
#                 Listed By CENTURY 21 Troop Real Estate
#
#           </div>
#  </div>, <div class="property-card-primary-info">
#  <div class="pdp-listing-type sale">FOR SALE</div>
#  <a class="listing-price" href="/property/1001-buena-vista-san-clemente-ca-92672-C2180898740">
#
#
#                 $1,699,000
#
#
#
#        </a>
#  <div class="col-wrap-mid">
#  <div class="property-beds">
#  <strong>2</strong> beds
#           </div>
#  <div class="property-baths">
#  <strong>2</strong> baths
#           </div>
#  </div>
#  <div class="col-wrap-last">
#  <div class="property-half-baths">
#  <strong>1</strong> half bath
#           </div>
#  </div>
#  <div class="property-address-info">
#  <div class="property-address" title="1001 Buena Vista">
#                 1001 Buena Vista
#              </div>
#  <div class="property-city">
#              San Clemente CA 92672
#           </div>
#  </div>
#  <div class="property-card-attribution">
#                 Listed By CENTURY 21 Award
#
#           </div>
#  </div>, <div class="property-card-primary-info">
#  <div class="pdp-listing-type sale">FOR SALE</div>
#  <a class="listing-price" href="/property/706-colleen-drive-san-jose-ca-95123-C2180898911">
#
#
#                 $1,499,000
#
#
#
#        </a>
#  <div class="col-wrap-mid">
#  <div class="property-beds">
#  <strong>4</strong> beds
#           </div>
#  <div class="property-baths">
#  <strong>2</strong> baths
#           </div>
#  </div>
#  <div class="col-wrap-last">
#  <div class="property-half-baths">
#  <strong>1</strong> half bath
#           </div>
#  <div class="property-sqft">
#  <strong>2,094</strong> sq. ft
#           </div>
#  </div>
#  <div class="property-address-info">
#  <div class="property-address" title="706 Colleen Drive">
#                 706 Colleen Drive
#              </div>
#  <div class="property-city">
#              San Jose CA 95123
#           </div>
#  </div>
#  <div class="property-card-attribution">
#                 Listed By CENTURY 21 MM
#
#           </div>
#  </div>, <div class="property-card-primary-info">
#  <div class="pdp-listing-type sale">FOR SALE</div>
#  <a class="listing-price" href="/property/1744-blakesley-dr-san-ramon-ca-94582-C2180898521">
#
#
#                 $1,195,000
#
#
#
#        </a>
#  <div class="col-wrap-mid">
#  <div class="property-beds">
#  <strong>4</strong> beds
#           </div>
#  <div class="property-baths">
#  <strong>3</strong> baths
#           </div>
#  </div>
#  <div class="col-wrap-last">
#  <div class="property-sqft">
#  <strong>2,378</strong> sq. ft
#           </div>
#  </div>
#  <div class="property-address-info">
#  <div class="property-address" title="1744 Blakesley Dr">
#                 1744 Blakesley Dr
#              </div>
#  <div class="property-city">
#              San Ramon CA 94582
#           </div>
#  </div>
#  <div class="property-card-attribution">
#                 Listed By CENTURY 21 Marquis
#
#           </div>
#  </div>, <div class="property-card-primary-info">
#  <div class="pdp-listing-type sale">FOR SALE</div>
#  <a class="listing-price" href="/property/593-buckeye-court-santa-rosa-ca-95409-C2180898517">
#
#
#                 $1,195,000
#
#
#
#        </a>
#  <div class="col-wrap-mid">
#  <div class="property-beds">
#  <strong>3</strong> beds
#           </div>
#  <div class="property-baths">
#  <strong>2</strong> baths
#           </div>
#  </div>
#  <div class="col-wrap-last">
#  <div class="property-half-baths">
#  <strong>1</strong> half bath
#           </div>
#  <div class="property-sqft">
#  <strong>2,108</strong> sq. ft
#           </div>
#  </div>
#  <div class="property-address-info">
#  <div class="property-address" title="593 Buckeye Court">
#                 593 Buckeye Court
#              </div>
#  <div class="property-city">
#              Santa Rosa CA 95409
#           </div>
#  </div>
#  <div class="property-card-attribution">
#                 Listed By CENTURY 21 Alliance
#
#           </div>
#  </div>, <div class="property-card-primary-info">
#  <div class="pdp-listing-type sale">FOR SALE</div>
#  <a class="listing-price" href="/property/21232-celtic-st-chatsworth-ca-91311-C2180898710">
#
#
#                 $1,070,000
#
#
#
#        </a>
#  <div class="col-wrap-mid">
#  <div class="property-beds">
#  <strong>5</strong> beds
#           </div>
#  <div class="property-baths">
#  <strong>3</strong> baths
#           </div>
#  </div>
#  <div class="col-wrap-last">
#  <div class="property-sqft">
#  <strong>3,006</strong> sq. ft
#           </div>
#  </div>
#  <div class="property-address-info">
#  <div class="property-address" title="21232 Celtic St">
#                 21232 Celtic St
#              </div>
#  <div class="property-city">
#              Chatsworth CA 91311
#           </div>
#  </div>
#  <div class="property-card-attribution">
#                 Listed By CENTURY 21 Troop Real Estate
#
#           </div>
#  </div>]

# %%
# Loop through x pages of the website with filter of Single House
page_link = 'https://www.century21.com/real-estate/california/LSCA/?sn=5&sk=Y&pt=1&p={}'
for link in [page_link.format(page) for page in range(1,4)]:
    res = requests.get(link)
    new_soup = BeautifulSoup(res.text, 'html.parser')
    new_results = new_soup.find_all('div', class_="property-card-primary-info")

    # Loop through returned results
    for result in new_results:
        # Error handling
        try:
            # Identify and return listing type
            listing_type = result.find('div', class_="pdp-listing-type").text
            # Identify and return price of House
            price = result.find('a', class_="listing-price").text
            # Identify and return number and street address of House
            street = result.find('div', class_="property-address").text
            # Identify and return city, state, and zip code of House
            city = result.find('div', class_="property-city").text
            # Identify and return room number of House
            bed = result.find('div', class_="property-beds").text
            # Identify and return bath number of House
            bath = result.find('div', class_="property-baths").text
            # Identify and return sqft of House
            sqft = result.find('div', class_="property-sqft").text

            # Print results only if title, price, and link are available
            if (listing_type and price and street and city and bed and bath and sqft):
                print('-------------')
                print(listing_type)
                print(price.strip())
                print(" ".join(street.split()))
                print(" ".join(city.split()))
                print(" ".join(bed.split()))
                print(" ".join(bath.split()))
                print(" ".join(sqft.split()))

        except AttributeError as e:
            continue
            # print(e)
# Out:
# -------------
# FOR SALE
# $949,500
# 340 Juanita Avenue
# Oceano CA 93445
# 4 beds
# 3 baths
# 2,166 sq. ft
# -------------
# FOR SALE
# $570,000
# 1033 Eclipse Way
# West Covina CA 91792
# 4 beds
# 2 baths
# 1,394 sq. ft
# -------------
# FOR SALE
# $300,000
# 23204 Cresta
# Twain Harte CA 95383
# 3 beds
# 1 bath
# 1,182 sq. ft
# -------------
# FOR SALE
# $223,000
# 3410 W Mesa
# Fresno CA 93711
# 3 beds
# 1 bath
# 1,100 sq. ft
# -------------
# FOR SALE
# $799,000
# 2342 Lakeview Dr
# San Leandro CA 94577
# 3 beds
# 2 baths
# 1,834 sq. ft
# -------------
# FOR SALE
# $750,000
# 528 Webster Dr
# Martinez CA 94553
# 4 beds
# 2 baths
# 1,430 sq. ft
# -------------
# FOR SALE
# $700,000
# 1553 Shelter Lane
# Murphys CA 95247
# 3 beds
# 2 baths
# 3,242 sq. ft
# -------------
# FOR SALE
# $525,000
# 30 Hampton Ct
# Oakley CA 94561
# 3 beds
# 2 baths
# 1,975 sq. ft
# -------------
# FOR SALE
# $2,495,000
# 1591 Lindacrest Dr
# Beverly Hills CA 90210
# 3 beds
# 3 baths
# 3,010 sq. ft
# -------------
# FOR SALE
# $1,499,000
# 706 Colleen Drive
# San Jose CA 95123
# 4 beds
# 2 baths
# 2,094 sq. ft
# -------------
# FOR SALE
# $1,195,000
# 1744 Blakesley Dr
# San Ramon CA 94582
# 4 beds
# 3 baths
# 2,378 sq. ft
# -------------
# FOR SALE
# $1,195,000
# 593 Buckeye Court
# Santa Rosa CA 95409
# 3 beds
# 2 baths
# 2,108 sq. ft
# -------------
# FOR SALE
# $1,070,000
# 21232 Celtic St
# Chatsworth CA 91311
# 5 beds
# 3 baths
# 3,006 sq. ft
# -------------
# FOR SALE
# $886,000
# 6315 Camino Corto
# San Diego CA 92120
# 5 beds
# 2 baths
# 2,535 sq. ft
# -------------
# FOR SALE
# $875,000
# 3621 Skyline Dr
# Hayward CA 94542
# 4 beds
# 2 baths
# 2,060 sq. ft
# -------------
# FOR SALE
# $839,888
# 3191 Flanagan Dr
# Simi Valley CA 93063
# 3 beds
# 2 baths
# 1,983 sq. ft
# -------------
# FOR SALE
# $799,000
# 11611 Lampson Avenue
# Garden Grove CA 92840
# 3 beds
# 2 baths
# 1,598 sq. ft
# -------------
# FOR SALE
# $798,888
# 167 E. Altadena Dr.
# Altadena CA 91001
# 3 beds
# 2 baths
# 1,698 sq. ft
# -------------
# FOR SALE
# $750,000
# 1865 El Monte Dr
# Thousand Oaks CA 91362
# 3 beds
# 2 baths
# 1,503 sq. ft
# -------------
# FOR SALE
# $1,219,000
# 23315 Susana Avenue
# Torrance CA 90505
# 4 beds
# 2 baths
# 1,684 sq. ft
# -------------
# FOR SALE
# $1,180,000
# 3775 Blanche Street
# Pasadena CA 91107
# 4 beds
# 13 baths
# 2,121 sq. ft
# -------------
# FOR SALE
# $1,169,880
# 1702 Tierra Court
# San Ramon CA 94583
# 4 beds
# 3 baths
# 2,316 sq. ft
# -------------
# FOR SALE
# $1,149,900
# 1216 Spar Ct
# Carlsbad CA 92011
# 4 beds
# 3 baths
# 3,245 sq. ft
# -------------
# FOR SALE
# $1,125,000
# 4030 Flowerwood Lane
# Fallbrook CA 92028
# 4 beds
# 4 baths
# 4,616 sq. ft
# -------------
# FOR SALE
# $1,125,000
# 95 Gardner Pl
# Danville CA 94526
# 3 beds
# 2 baths
# 2,486 sq. ft
# -------------
# FOR SALE
# $1,100,000
# 10683 E San Jose Avenue
# Clovis CA 93619
# 6 beds
# 5 baths
# 4,970 sq. ft
# -------------
# FOR SALE
# $1,099,900
# 10461 Monterey Ridge Dr
# San Diego CA 92127
# 5 beds
# 3 baths
# 3,080 sq. ft
# -------------
# FOR SALE
# $1,095,000
# 368 Lark Ellen Avenue
# Ojai CA 93023
# 3 beds
# 2 baths
# 1,819 sq. ft
# -------------
# FOR SALE
# $1,090,000
# 6816 Thornhill Dr
# Oakland CA 94611
# 4 beds
# 3 baths
# 2,111 sq. ft
# -------------
# FOR SALE
# $1,089,000
# 6 Andria
# Irvine CA 92614
# 3 beds
# 2 baths
# 2,187 sq. ft
# -------------
# FOR SALE
# $1,089,000
# 4218 Gentry
# Studio City CA 91604
# 2 beds
# 2 baths
# 1,520 sq. ft
# -------------
# FOR SALE
# $1,075,000
# 22261 Cass Avenue
# Woodland Hills CA 91364
# 4 beds
# 3 baths
# 2,904 sq. ft
# -------------
# FOR SALE
# $1,075,000
# 2605 Inglewood Avenue
# Redondo Beach CA 90278
# 4 beds
# 3 baths
# 2,442 sq. ft
# -------------
# FOR SALE
# $1,056,000
# 13363 Benchely Road
# San Diego CA 92130
# 4 beds
# 3 baths
# 2,103 sq. ft
# -------------
# FOR SALE
# $1,050,000
# 910 Red Rock Road
# Arroyo Grande CA 93420
# 6 beds
# 3 baths
# 3,900 sq. ft
# -------------
# FOR SALE
# $1,050,000
# 29214 Black Pine Way
# Saugus CA 91390
# 4 beds
# 4 baths
# 3,526 sq. ft
# -------------
# FOR SALE
# $1,025,000
# 1635 Blue Canyon Street
# Newbury Park CA 91320
# 4 beds
# 3 baths
# 3,187 sq. ft
# -------------
# FOR SALE
# $999,000
# 19691 Dorado Drive
# Lake Forest CA 92679
# 5 beds
# 4 baths
# 3,514 sq. ft
# -------------
# FOR SALE
# $995,000
# 2952 Vine Hill Rd
# Oakley CA 94561
# 4 beds
# 3 baths
# 4,385 sq. ft
# -------------
# FOR SALE
# $725,000
# 2574 High Trail Court
# Chula Vista CA 91914
# 5 beds
# 3 baths
# 2,427 sq. ft
# -------------
# FOR SALE
# $725,000
# 23585 Rangoon Street
# Mission Viejo CA 92691
# 4 beds
# 2 baths
# 2,415 sq. ft
# -------------
# FOR SALE
# $715,000
# 442 Calla Ave
# Imperial Beach CA 91932
# 3 beds
# 2 baths
# 1,500 sq. ft
# -------------
# FOR SALE
# $710,000
# 15865 Via Conejo
# San Lorenzo CA 94580
# 4 beds
# 2 baths
# 2,000 sq. ft
# -------------
# FOR SALE
# $705,000
# 6930 Beloit Ave
# San Diego CA 92111
# 3 beds
# 2 baths
# 1,440 sq. ft
# -------------
# FOR SALE
# $702,498
# 9760 N Lucy Lane
# Northridge CA 91325
# 4 beds
# 3 baths
# 2,010 sq. ft
# -------------
# FOR SALE
# $699,999
# 14909 Four Corners Trail
# Ramona CA 92065
# 4 beds
# 3 baths
# 2,751 sq. ft
# -------------
# FOR SALE
# $699,900
# 32302 Cahuka Court
# Pauma Valley CA 92061
# 4 beds
# 3 baths
# 3,028 sq. ft
# -------------
# FOR SALE
# $699,000
# 2660 Serena Avenue
# Clovis CA 93619
# 5 beds
# 3 baths
# 4,189 sq. ft
# -------------
# FOR SALE
# $699,000
# 11391 Westonhill Dr
# San Diego CA 92126
# 5 beds
# 3 baths
# 2,255 sq. ft
# -------------
# FOR SALE
# $699,000
# 3183 Bear Creek Drive
# Newbury Park CA 91320
# 3 beds
# 2 baths
# 1,814 sq. ft
# -------------
# FOR SALE
# $699,000
# 17047 New Rochelle Way
# San Diego CA 92127
# 3 beds
# 2 baths
# 1,455 sq. ft
# -------------
# FOR SALE
# $695,000
# 6859 Cowles Mountain Blvd
# San Diego CA 92119
# 4 beds
# 2 baths
# 1,845 sq. ft
# -------------
# FOR SALE
# $695,000
# 30235 Ynez Road
# Temecula CA 92592
# 3 beds
# 1 bath
# 1,782 sq. ft
# -------------
# FOR SALE
# $695,000
# 6045 Paseo Carreta
# Carlsbad CA 92009
# 3 beds
# 2 baths
# 1,600 sq. ft
# -------------
# FOR SALE
# $687,000
# 2834 Carlton Way
# Fallbrook CA 92028
# 3 beds
# 2 baths
# 2,407 sq. ft
# -------------
# FOR SALE
# $685,000
# 2909 Spanish Bay Dr
# Brentwood CA 94513
# 4 beds
# 2 baths
# 3,622 sq. ft
# -------------
# FOR SALE
# $675,000
# 5926 Cypress Point Avenue
# Long Beach CA 90808
# 4 beds
# 2 baths
# 2,078 sq. ft
# -------------
# FOR SALE
# $675,000
# 325 S Vine Street
# Paso Robles CA 93446
# 3 beds
# 2 baths
# 1,749 sq. ft
# -------------
# FOR SALE
# $670,000
# 5423 Sapphire Street
# Alta Loma CA 91701
# 4 beds
# 2 baths
# 2,103 sq. ft
