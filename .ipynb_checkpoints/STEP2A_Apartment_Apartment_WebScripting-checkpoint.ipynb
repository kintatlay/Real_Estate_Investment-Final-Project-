# %%
# Dependencies
from bs4 import BeautifulSoup
import requests
import pandas as pd
import re

# %%
#Testing
scrape_link = 'https://www.apartments.com/apartments/ca/'

response = requests.get(scrape_link)
soup = BeautifulSoup(response.text, 'html.parser')
result = soup.find_all('div', class_="placardContainer")
result
# Out:
# [<div class="placardContainer" id="placardContainer">
#  <ul>
#  <li>
#  <article class="diamond placard" data-ck="fgm2gzv" data-listingid="y9fg55t" data-url="https://www.apartments.com/homecoming-at-eastvale-eastvale-ca/y9fg55t/">
#  <header class="placardHeader">
#  <a class="placardTitle js-placardTitle " href="https://www.apartments.com/homecoming-at-eastvale-eastvale-ca/y9fg55t/" title="Homecoming At Eastvale, Eastvale, CA">
#  Homecoming At Eastvale</a>
#  <img alt="Lewis Management Corp" class="propertyLogo" src="https://images1.apartments.com/i2/8oJ0IbanGmv-y64BtgyDHrIkQjD07arn9GPAfsdd30g/110/lewis-management-corp-logo.png"/>
#  <div class="location" title="5464 W Homecoming Cir, Eastvale, CA 91752">5464 W Homecoming Cir, Eastvale, CA 91752</div>
#  </header>
#  <section class="placardContent">
#  <div class="media">
#  <div class="placardCarouselImgCount">
#  <span class="js-spnImgNum">1</span> / <span class="js-spnImgCount">25</span>
#  </div>
#  <div class="galleryControl">
#  <button class="imageCarouselLeftContainer" type="button">
#  <i class="imageCarouselArrowLeftIcon"></i>
#  </button>
#  <button class="imageCarouselRightContainer" type="button">
#  <i class="imageCarouselArrowRightIcon"></i>
#  </button>
#  </div>
#  <div class="imageContainer carousel slide" data-interval="false">
#  <div class="carouselSpinner">
#  <i class="aptsLogoMarkIcon rotate"></i>
#  </div>
#  <div class="fallbackSpinner">
#  <i class="spinner"></i>
#  </div>
#  <div class="carouselInner">
#  <div class="item active " style='background-image: url("https://images1.apartments.com/i2/DeV2mUx-3wdSPXfG7t9anq0dg4vrfT1h-XaX99Eof00/111/homecoming-at-eastvale-eastvale-ca-building-photo.jpg");' title="Building Photo - Homecoming At Eastvale">
#  </div>
#  </div>
#  </div>
#  <div class="placardBanner">
#  <button class="virtualTour" title="See Homecoming At Eastvale in 3D" type="button">
#  <i class="threeDIcon"></i>
#  </button>
#  </div>
#  </div>
#  <div class="propertyInfo">
#  <div class="infoPadding">
#  <div class="freshnessAndFavoritesWrapper">
#  <span class="listingFreshness">
#  <span class="lastUpdated">
#  <i class="clockIcon" title="Last Updated"></i>
#  <span>2 hrs</span>
#  </span>
#  </span>
#  <a class="favoriteIcon neutral" data-liked-classes="liked" data-neutral-classes="neutral" href="javascript:void(0);"></a> </div>
#  <div class="apartmentRentRollupContainer">
#  <span class="altRentDisplay">$1,788 - 2,527</span>
#  <span class="unitLabel ">1-3 Bed</span>
#  <span class="availabilityDisplay noBedSelected ">Available Now</span>
#  </div>
#  <ul class="amenities">
#  <li class="petIcon" title="Dogs"></li>
#  <li class="catIcon" title="Cats"></li>
#  <li class="carIcon" title="Parking"></li>
#  <li class="fitnessIcon" title="Fitness Center"></li>
#  </ul>
#  <div class="contactInfo ">
#  <div class="phone">
#  <i class="phoneIcon"></i>
#  <span>877-763-1054</span>
#  </div>
#  </div>
#  <button class="checkAvailability" data-lang="en" title="Get more information about Homecoming At Eastvale">
#  <i class="emailIcon"></i>
#  <span class="label">Email Property</span>
#  <span class="shortLabel">Email</span>
#  </button>
#  </div>
#  </div>
#  </section>
#  </article>
#  </li>
#  <li>
#  <article class="diamond placard" data-ck="dv0gtnl" data-listingid="2j8hjp8" data-url="https://www.apartments.com/the-pearl-los-angeles-ca/2j8hjp8/">
#  <header class="placardHeader">
#  <a class="placardTitle js-placardTitle " href="https://www.apartments.com/the-pearl-los-angeles-ca/2j8hjp8/" title="The Pearl, Los Angeles, CA">
#  The Pearl</a>
#  <img alt="Greystar Real Estate Partners" class="propertyLogo" src="https://images1.apartments.com/i2/6hmOJG25BQyrzwHxc2UNnUzFro76tRZnuGEbj8wq2jA/110/greystar-real-estate-partners-logo.png"/>
#  <div class="location" title="687 S Hobart Blvd, Los Angeles, CA 90005">687 S Hobart Blvd, Los Angeles, CA 90005</div>
#  </header>
#  <section class="placardContent">
#  <div class="media">
#  <div class="placardCarouselImgCount">
#  <span class="js-spnImgNum">1</span> / <span class="js-spnImgCount">46</span>
#  </div>
#  <div class="galleryControl">
#  <button class="imageCarouselLeftContainer" type="button">
#  <i class="imageCarouselArrowLeftIcon"></i>
#  </button>
#  <button class="imageCarouselRightContainer" type="button">
#  <i class="imageCarouselArrowRightIcon"></i>
#  </button>
#  </div>
#  <div class="imageContainer carousel slide" data-interval="false">
#  <div class="carouselSpinner">
#  <i class="aptsLogoMarkIcon rotate"></i>
#  </div>
#  <div class="fallbackSpinner">
#  <i class="spinner"></i>
#  </div>
#  <div class="carouselInner">
#  <div class="item active " style='background-image: url("https://images1.apartments.com/i2/XFY6vOy0Z4SeOxgxeIluxswBpt-0v9ivC9psnlQCHlk/111/the-pearl-los-angeles-ca-building-photo.jpg");' title="Building Photo - The Pearl">
#  </div>
#  </div>
#  </div>
#  <div class="placardBanner">
#  <button class="virtualTour" title="See The Pearl in 3D" type="button">
#  <i class="threeDIcon"></i>
#  </button>
#  </div>
#  </div>
#  <div class="propertyInfo">
#  <div class="infoPadding">
#  <div class="freshnessAndFavoritesWrapper">
#  <span class="listingFreshness">
#  <span class="new">
#  <i class="alertLightningBoltIcon" title="New"></i>
#  <span>New</span>
#  </span>
#  </span>
#  <a class="favoriteIcon neutral" data-liked-classes="liked" data-neutral-classes="neutral" href="javascript:void(0);"></a> </div>
#  <div class="apartmentRentRollupContainer">
#  <span class="altRentDisplay">$1,879 - 3,322</span>
#  <span class="unitLabel ">Studio - 2 Bed</span>
#  <span class="availabilityDisplay noBedSelected ">Available Now</span>
#  </div>
#  <ul class="amenities">
#  <li class="petIcon" title="Dogs"></li>
#  <li class="catIcon" title="Cats"></li>
#  <li class="airConditionerIcon" title="Air Conditioning"></li>
#  <li class="laundryIcon" title="Washer/Dryer"></li>
#  <li class="carIcon" title="Parking"></li>
#  </ul>
#  <div class="contactInfo ">
#  <div class="phone">
#  <i class="phoneIcon"></i>
#  <span>844-781-2007</span>
#  </div>
#  </div>
#  <button class="checkAvailability" data-lang="en" title="Get more information about The Pearl">
#  <i class="emailIcon"></i>
#  <span class="label">Email Property</span>
#  <span class="shortLabel">Email</span>
#  </button>
#  </div>
#  </div>
#  </section>
#  </article>
#  </li>
#  <li>
#  <article class="diamond placard" data-ck="16xx9c5" data-listingid="fcsfr7r" data-url="https://www.apartments.com/the-falls-at-willow-creek-folsom-ca/fcsfr7r/">
#  <header class="placardHeader">
#  <a class="placardTitle js-placardTitle " href="https://www.apartments.com/the-falls-at-willow-creek-folsom-ca/fcsfr7r/" title="The Falls at Willow Creek, Folsom, CA">
#  The Falls at Willow Creek</a>
#  <img alt="Gerson Bakar &amp; Associates" class="propertyLogo" src="https://images1.apartments.com/i2/hvBxrxCBf-gEPf9quTacaqdYOSSqMKYdRFtmoKUA6Js/110/gerson-bakar-associates-logo.png"/>
#  <div class="location" title="1780 Creekside Dr, Folsom, CA 95630">1780 Creekside Dr, Folsom, CA 95630</div>
#  </header>
#  <section class="placardContent">
#  <div class="media">
#  <div class="placardCarouselImgCount">
#  <span class="js-spnImgNum">1</span> / <span class="js-spnImgCount">58</span>
#  </div>
#  <div class="galleryControl">
#  <button class="imageCarouselLeftContainer" type="button">
#  <i class="imageCarouselArrowLeftIcon"></i>
#  </button>
#  <button class="imageCarouselRightContainer" type="button">
#  <i class="imageCarouselArrowRightIcon"></i>
#  </button>
#  </div>
#  <div class="imageContainer carousel slide" data-interval="false">
#  <div class="carouselSpinner">
#  <i class="aptsLogoMarkIcon rotate"></i>
#  </div>
#  <div class="fallbackSpinner">
#  <i class="spinner"></i>
#  </div>
#  <div class="carouselInner">
#  <div class="item active " style='background-image: url("https://images1.apartments.com/i2/09t46V4AJtKmXAjg9U6XsMLf7cgV9P5wfzdjgzM3028/111/the-falls-at-willow-creek-folsom-ca-building-photo.jpg");' title="Building Photo - The Falls at Willow Creek">
#  </div>
#  </div>
#  </div>
#  <div class="placardBanner">
#  <button class="virtualTour" title="See The Falls at Willow Creek in 3D" type="button">
#  <i class="threeDIcon"></i>
#  </button>
#  </div>
#  </div>
#  <div class="propertyInfo">
#  <div class="infoPadding">
#  <div class="freshnessAndFavoritesWrapper">
#  <span class="listingFreshness">
#  <span class="new">
#  <i class="alertLightningBoltIcon" title="New"></i>
#  <span>New</span>
#  </span>
#  </span>
#  <a class="favoriteIcon neutral" data-liked-classes="liked" data-neutral-classes="neutral" href="javascript:void(0);"></a> </div>
#  <div class="apartmentRentRollupContainer">
#  <span class="altRentDisplay">$1,450 - 2,365</span>
#  <span class="unitLabel ">1-3 Bed</span>
#  <span class="availabilityDisplay noBedSelected ">Available Now</span>
#  </div>
#  <ul class="amenities">
#  <li class="petIcon" title="Dogs"></li>
#  <li class="catIcon" title="Cats"></li>
#  <li class="airConditionerIcon" title="Air Conditioning"></li>
#  <li class="laundryIcon" title="Washer/Dryer"></li>
#  <li class="dishWasherIcon" title="Dishwasher"></li>
#  </ul>
#  <div class="contactInfo ">
#  <div class="phone">
#  <i class="phoneIcon"></i>
#  <span>844-415-9177</span>
#  </div>
#  </div>
#  <button class="checkAvailability" data-lang="en" title="Get more information about The Falls at Willow Creek">
#  <i class="emailIcon"></i>
#  <span class="label">Email Property</span>
#  <span class="shortLabel">Email</span>
#  </button>
#  </div>
#  </div>
#  </section>
#  </article>
#  </li>
#  <li>
#  <article class="diamond placard" data-ck="dv0gtnl" data-listingid="f7hz5nr" data-url="https://www.apartments.com/westcreek-apartments-westlake-village-ca/f7hz5nr/">
#  <header class="placardHeader">
#  <a class="placardTitle js-placardTitle " href="https://www.apartments.com/westcreek-apartments-westlake-village-ca/f7hz5nr/" title="Westcreek Apartments, Westlake Village, CA">
#  Westcreek Apartments</a>
#  <img alt="Greystar Real Estate Partners" class="propertyLogo" src="https://images1.apartments.com/i2/6hmOJG25BQyrzwHxc2UNnUzFro76tRZnuGEbj8wq2jA/110/greystar-real-estate-partners-logo.png"/>
#  <div class="location" title="973-986 Westcreek Ln, Westlake Village, CA 91362">973-986 Westcreek Ln, Westlake Village, CA 91362</div>
#  </header>
#  <section class="placardContent">
#  <div class="media">
#  <div class="placardCarouselImgCount">
#  <span class="js-spnImgNum">1</span> / <span class="js-spnImgCount">32</span>
#  </div>
#  <div class="galleryControl">
#  <button class="imageCarouselLeftContainer" type="button">
#  <i class="imageCarouselArrowLeftIcon"></i>
#  </button>
#  <button class="imageCarouselRightContainer" type="button">
#  <i class="imageCarouselArrowRightIcon"></i>
#  </button>
#  </div>
#  <div class="imageContainer carousel slide" data-interval="false">
#  <div class="carouselSpinner">
#  <i class="aptsLogoMarkIcon rotate"></i>
#  </div>
#  <div class="fallbackSpinner">
#  <i class="spinner"></i>
#  </div>
#  <div class="carouselInner">
#  <div class="item active " style='background-image: url("https://images1.apartments.com/i2/4KTS9SdR-fjtzZuNCNN2qO6X3Cfaqs4ohzJzMEUgqrY/111/westcreek-apartments-westlake-village-ca-building-photo.jpg");' title="Building Photo - Westcreek Apartments">
#  </div>
#  </div>
#  </div>
#  <div class="placardBanner">
#  <button class="virtualTour" title="See Westcreek Apartments in 3D" type="button">
#  <i class="threeDIcon"></i>
#  </button>
#  </div>
#  </div>
#  <div class="propertyInfo">
#  <div class="infoPadding">
#  <div class="freshnessAndFavoritesWrapper">
#  <span class="listingFreshness">
#  <span class="lastUpdated">
#  <i class="clockIcon" title="Last Updated"></i>
#  <span>2 hrs</span>
#  </span>
#  </span>
#  <a class="favoriteIcon neutral" data-liked-classes="liked" data-neutral-classes="neutral" href="javascript:void(0);"></a> </div>
#  <div class="apartmentRentRollupContainer">
#  <span class="altRentDisplay">$2,128 - 4,557</span>
#  <span class="unitLabel ">1-2 Bed</span>
#  <span class="availabilityDisplay noBedSelected ">Available Now</span>
#  </div>
#  <ul class="amenities">
#  <li class="petIcon" title="Dogs"></li>
#  <li class="catIcon" title="Cats"></li>
#  <li class="carIcon" title="Parking"></li>
#  <li class="fitnessIcon" title="Fitness Center"></li>
#  </ul>
#  <div class="contactInfo ">
#  <div class="phone">
#  <i class="phoneIcon"></i>
#  <span>818-584-7952</span>
#  </div>
#  </div>
#  <button class="checkAvailability" data-lang="en" title="Get more information about Westcreek Apartments">
#  <i class="emailIcon"></i>
#  <span class="label">Email Property</span>
#  <span class="shortLabel">Email</span>
#  </button>
#  </div>
#  </div>
#  </section>
#  </article>
#  </li>
#  <li>
#  <article class="diamond placard" data-ck="6kcwtlr" data-listingid="hh7p150" data-url="https://www.apartments.com/vista-gardens-apartments-hemet-ca/hh7p150/">
#  <header class="placardHeader">
#  <a class="placardTitle js-placardTitle " href="https://www.apartments.com/vista-gardens-apartments-hemet-ca/hh7p150/" title="Vista Gardens Apartments, Hemet, CA">
#  Vista Gardens Apartments</a>
#  <img alt="CTM Apartment Services" class="propertyLogo" src="https://images1.apartments.com/i2/ba-wJoBgb-o2uLCPiwVnZ0KhexeWe2cCkzDoYc24Zuc/110/ctm-apartment-services-logo.png"/>
#  <div class="location" title="555 E Fruitvale Ave, Hemet, CA 92543">555 E Fruitvale Ave, Hemet, CA 92543</div>
#  </header>
#  <section class="placardContent">
#  <div class="media">
#  <div class="placardCarouselImgCount">
#  <span class="js-spnImgNum">1</span> / <span class="js-spnImgCount">29</span>
#  </div>
#  <div class="galleryControl">
#  <button class="imageCarouselLeftContainer" type="button">
#  <i class="imageCarouselArrowLeftIcon"></i>
#  </button>
#  <button class="imageCarouselRightContainer" type="button">
#  <i class="imageCarouselArrowRightIcon"></i>
#  </button>
#  </div>
#  <div class="imageContainer carousel slide" data-interval="false">
#  <div class="carouselSpinner">
#  <i class="aptsLogoMarkIcon rotate"></i>
#  </div>
#  <div class="fallbackSpinner">
#  <i class="spinner"></i>
#  </div>
#  <div class="carouselInner">
#  <div class="item active " data-image="https://images1.apartments.com/i2/OHeJ20yJr3Y5jbjo-IYT4dwnXpu6gaoMGWhleVFh1is/111/vista-gardens-apartments-hemet-ca-building-photo.jpg" title="Building Photo - Vista Gardens Apartments">
#  </div>
#  </div>
#  </div>
#  <div class="placardBanner">
#  <button class="virtualTour" title="See Vista Gardens Apartments in 3D" type="button">
#  <i class="threeDIcon"></i>
#  </button>
#  </div>
#  </div>
#  <div class="propertyInfo">
#  <div class="infoPadding">
#  <div class="freshnessAndFavoritesWrapper">
#  <span class="listingFreshness">
#  <span class="lastUpdated">
#  <i class="clockIcon" title="Last Updated"></i>
#  <span>2 wks</span>
#  </span>
#  </span>
#  <a class="favoriteIcon neutral" data-liked-classes="liked" data-neutral-classes="neutral" href="javascript:void(0);"></a> </div>
#  <div class="apartmentRentRollupContainer">
#  <span class="altRentDisplay">$1,005 - 1,210</span>
#  <span class="unitLabel ">1-2 Bed</span>
#  <span class="availabilityDisplay noBedSelected ">Available Now</span>
#  </div>
#  <ul class="amenities">
#  <li class="airConditionerIcon" title="Air Conditioning"></li>
#  <li class="dishWasherIcon" title="Dishwasher"></li>
#  <li class="carIcon" title="Parking"></li>
#  </ul>
#  <div class="contactInfo ">
#  <div class="phone">
#  <i class="phoneIcon"></i>
#  <span>951-305-4919</span>
#  </div>
#  </div>
#  <button class="checkAvailability" data-lang="en,es" title="Get more information about Vista Gardens Apartments">
#  <i class="emailIcon"></i>
#  <span class="label">Email Property</span>
#  <span class="shortLabel">Email</span>
#  </button>
#  </div>
#  </div>
#  </section>
#  </article>
#  </li>
#  <li>
#  <article class="diamond placard" data-ck="0xj1hy3" data-listingid="j482kt6" data-url="https://www.apartments.com/the-jackson-anaheim-ca/j482kt6/">
#  <header class="placardHeader">
#  <a class="placardTitle js-placardTitle " href="https://www.apartments.com/the-jackson-anaheim-ca/j482kt6/" title="The Jackson, Anaheim, CA">
#  The Jackson</a>
#  <img alt="Advanced Real Estate Services Inc" class="propertyLogo" src="https://images1.apartments.com/i2/DxsHG7Up6DW44yPI3xgsmbmqA_98ZR52f4WmoP73DLM/110/advanced-real-estate-services-inc-logo.png"/>
#  <div class="location" title="2960-2965 E Jackson Ave, Anaheim, CA 92806">2960-2965 E Jackson Ave, Anaheim, CA 92806</div>
#  </header>
#  <section class="placardContent">
#  <div class="media">
#  <div class="placardCarouselImgCount">
#  <span class="js-spnImgNum">1</span> / <span class="js-spnImgCount">83</span>
#  </div>
#  <div class="galleryControl">
#  <button class="imageCarouselLeftContainer" type="button">
#  <i class="imageCarouselArrowLeftIcon"></i>
#  </button>
#  <button class="imageCarouselRightContainer" type="button">
#  <i class="imageCarouselArrowRightIcon"></i>
#  </button>
#  </div>
#  <div class="imageContainer carousel slide" data-interval="false">
#  <div class="carouselSpinner">
#  <i class="aptsLogoMarkIcon rotate"></i>
#  </div>
#  <div class="fallbackSpinner">
#  <i class="spinner"></i>
#  </div>
#  <div class="carouselInner">
#  <div class="item active " data-image="https://images1.apartments.com/i2/McLWhnLswzlLrs7QXXwE7sNItvxcy4SFFu_xnp1hTiY/111/the-jackson-anaheim-ca-building-photo.jpg" title="Building Photo - The Jackson">
#  </div>
#  </div>
#  </div>
#  <div class="placardBanner">
#  <button class="videoPlay" data-video="https://s.lnimg.com/video/play/Cjt2dnH3A" title="Watch The Jackson Video" type="button">
#  <i class="playVideoPlacardIcon"></i>
#  </button>
#  <button class="virtualTour" title="See The Jackson in 3D" type="button">
#  <i class="threeDIcon"></i>
#  </button>
#  </div>
#  </div>
#  <div class="propertyInfo">
#  <div class="infoPadding">
#  <div class="freshnessAndFavoritesWrapper">
#  <span class="listingFreshness">
#  <span class="lastUpdated">
#  <i class="clockIcon" title="Last Updated"></i>
#  <span>8 hrs</span>
#  </span>
#  </span>
#  <a class="favoriteIcon neutral" data-liked-classes="liked" data-neutral-classes="neutral" href="javascript:void(0);"></a> </div>
#  <div class="apartmentRentRollupContainer">
#  <span class="altRentDisplay">$1,600 - 2,245</span>
#  <span class="unitLabel ">1-2 Bed</span>
#  <span class="availabilityDisplay noBedSelected ">Available Now</span>
#  </div>
#  <ul class="amenities">
#  <li class="petIcon" title="Dogs"></li>
#  <li class="catIcon" title="Cats"></li>
#  <li class="airConditionerIcon" title="Air Conditioning"></li>
#  <li class="dishWasherIcon" title="Dishwasher"></li>
#  <li class="carIcon" title="Parking"></li>
#  </ul>
#  <div class="contactInfo ">
#  <div class="phone">
#  <i class="phoneIcon"></i>
#  <span>844-865-2720</span>
#  </div>
#  </div>
#  <button class="checkAvailability" data-lang="en" title="Get more information about The Jackson">
#  <i class="emailIcon"></i>
#  <span class="label">Email Property</span>
#  <span class="shortLabel">Email</span>
#  </button>
#  </div>
#  </div>
#  </section>
#  </article>
#  </li>
#  <li>
#  <article class="diamond placard" data-ck="ekyrl9p" data-listingid="ppzz9pr" data-url="https://www.apartments.com/wedgewood-apartments-sacramento-ca/ppzz9pr/">
#  <header class="placardHeader">
#  <a class="placardTitle js-placardTitle " href="https://www.apartments.com/wedgewood-apartments-sacramento-ca/ppzz9pr/" title="Wedgewood Apartments, Sacramento, CA">
#  Wedgewood Apartments</a>
#  <img alt="FPI Management" class="propertyLogo" src="https://images1.apartments.com/i2/1xOKZj7FniwXJ6buHSZxzG9gi1Qutx3JAn3or0Iod2Q/110/fpi-management-logo.png"/>
#  <div class="location" title="941 43rd Ave, Sacramento, CA 95831">941 43rd Ave, Sacramento, CA 95831</div>
#  </header>
#  <section class="placardContent">
#  <div class="media">
#  <div class="placardCarouselImgCount">
#  <span class="js-spnImgNum">1</span> / <span class="js-spnImgCount">66</span>
#  </div>
#  <div class="galleryControl">
#  <button class="imageCarouselLeftContainer" type="button">
#  <i class="imageCarouselArrowLeftIcon"></i>
#  </button>
#  <button class="imageCarouselRightContainer" type="button">
#  <i class="imageCarouselArrowRightIcon"></i>
#  </button>
#  </div>
#  <div class="imageContainer carousel slide" data-interval="false">
#  <div class="carouselSpinner">
#  <i class="aptsLogoMarkIcon rotate"></i>
#  </div>
#  <div class="fallbackSpinner">
#  <i class="spinner"></i>
#  </div>
#  <div class="carouselInner">
#  <div class="item active " data-image="https://images1.apartments.com/i2/tL4-zE24O-BqeVc9xXV84S7pgbi4WK8fEbzao4xwGeE/111/wedgewood-apartments-sacramento-ca-building-photo.jpg" title="Building Photo - Wedgewood Apartments">
#  </div>
#  </div>
#  </div>
#  <div class="placardBanner">
#  </div>
#  </div>
#  <div class="propertyInfo">
#  <div class="infoPadding">
#  <div class="freshnessAndFavoritesWrapper">
#  <span class="listingFreshness">
#  <span class="lastUpdated">
#  <i class="clockIcon" title="Last Updated"></i>
#  <span>2 hrs</span>
#  </span>
#  </span>
#  <a class="favoriteIcon neutral" data-liked-classes="liked" data-neutral-classes="neutral" href="javascript:void(0);"></a> </div>
#  <div class="apartmentRentRollupContainer">
#  <span class="altRentDisplay">$1,058 - 1,669</span>
#  <span class="unitLabel ">Studio - 3 Bed</span>
#  <span class="availabilityDisplay noBedSelected ">Available Now</span>
#  </div>
#  <ul class="amenities">
#  <li class="petIcon" title="Dogs"></li>
#  <li class="catIcon" title="Cats"></li>
#  <li class="airConditionerIcon" title="Air Conditioning"></li>
#  <li class="laundryIcon" title="Washer/Dryer"></li>
#  <li class="dishWasherIcon" title="Dishwasher"></li>
#  </ul>
#  <div class="contactInfo ">
#  <div class="phone">
#  <i class="phoneIcon"></i>
#  <span>844-411-0703</span>
#  </div>
#  </div>
#  <button class="checkAvailability" data-lang="en" title="Get more information about Wedgewood Apartments">
#  <i class="emailIcon"></i>
#  <span class="label">Email Property</span>
#  <span class="shortLabel">Email</span>
#  </button>
#  </div>
#  </div>
#  </section>
#  </article>
#  </li>
#  <li>
#  <article class="diamond placard" data-ck="k14nn0c" data-listingid="w4ek4pk" data-url="https://www.apartments.com/eaves-fremont-fremont-ca/w4ek4pk/">
#  <header class="placardHeader">
#  <a class="placardTitle js-placardTitle " href="https://www.apartments.com/eaves-fremont-fremont-ca/w4ek4pk/" title="eaves Fremont, Fremont, CA">
#  eaves Fremont</a>
#  <img alt="AvalonBay Communities, Inc." class="propertyLogo" src="https://images1.apartments.com/i2/YEDm1liZ2LXsjltF9Lsu6iiMccDqBPVRV_1lhoEtqCw/110/avalonbay-communities-inc-logo.png"/>
#  <div class="location" title="231 Woodcreek Commons, Fremont, CA 94539">231 Woodcreek Commons, Fremont, CA 94539</div>
#  </header>
#  <section class="placardContent">
#  <div class="media">
#  <div class="placardCarouselImgCount">
#  <span class="js-spnImgNum">1</span> / <span class="js-spnImgCount">21</span>
#  </div>
#  <div class="galleryControl">
#  <button class="imageCarouselLeftContainer" type="button">
#  <i class="imageCarouselArrowLeftIcon"></i>
#  </button>
#  <button class="imageCarouselRightContainer" type="button">
#  <i class="imageCarouselArrowRightIcon"></i>
#  </button>
#  </div>
#  <div class="imageContainer carousel slide" data-interval="false">
#  <div class="carouselSpinner">
#  <i class="aptsLogoMarkIcon rotate"></i>
#  </div>
#  <div class="fallbackSpinner">
#  <i class="spinner"></i>
#  </div>
#  <div class="carouselInner">
#  <div class="item active " data-image="https://images1.apartments.com/i2/7FrsNdSoEIfoyH8YbqWzUk7Jz8ES-y0X60GmMFeQBuY/111/eaves-fremont-fremont-ca-building-photo.jpg" title="Building Photo - eaves Fremont">
#  </div>
#  </div>
#  </div>
#  <div class="placardBanner">
#  </div>
#  </div>
#  <div class="propertyInfo">
#  <div class="infoPadding">
#  <div class="freshnessAndFavoritesWrapper">
#  <span class="listingFreshness">
#  <span class="lastUpdated">
#  <i class="clockIcon" title="Last Updated"></i>
#  <span>1 day</span>
#  </span>
#  </span>
#  <a class="favoriteIcon neutral" data-liked-classes="liked" data-neutral-classes="neutral" href="javascript:void(0);"></a> </div>
#  <div class="apartmentRentRollupContainer">
#  <span class="altRentDisplay">$2,305 - 2,920</span>
#  <span class="unitLabel ">1-2 Bed</span>
#  <span class="availabilityDisplay noBedSelected ">Available Now</span>
#  </div>
#  <ul class="amenities">
#  <li class="petIcon" title="Dogs"></li>
#  <li class="catIcon" title="Cats"></li>
#  <li class="airConditionerIcon" title="Air Conditioning"></li>
#  <li class="laundryIcon" title="Washer/Dryer"></li>
#  <li class="carIcon" title="Parking"></li>
#  </ul>
#  <div class="contactInfo ">
#  <div class="phone">
#  <i class="phoneIcon"></i>
#  <span>855-223-3703</span>
#  </div>
#  </div>
#  <button class="checkAvailability" data-lang="en" title="Get more information about eaves Fremont">
#  <i class="emailIcon"></i>
#  <span class="label">Email Property</span>
#  <span class="shortLabel">Email</span>
#  </button>
#  </div>
#  </div>
#  </section>
#  </article>
#  </li>
#  <li>
#  <article class="diamond placard" data-ck="dv0gtnl" data-listingid="bwf9tt8" data-url="https://www.apartments.com/harrison-glendale-ca/bwf9tt8/">
#  <header class="placardHeader">
#  <a class="placardTitle js-placardTitle " href="https://www.apartments.com/harrison-glendale-ca/bwf9tt8/" title="Harrison, Glendale, CA">
#  Harrison</a>
#  <img alt="Greystar Real Estate Partners" class="propertyLogo" src="https://images1.apartments.com/i2/otBeGFzvxl_aZj7gHsz-hloHOCkPzBcIzlpt3FIz1Tk/110/greystar-real-estate-partners-logo.png"/>
#  <div class="location" title="318 W Wilson Ave, Glendale, CA 91203">318 W Wilson Ave, Glendale, CA 91203</div>
#  </header>
#  <section class="placardContent">
#  <div class="media">
#  <div class="placardCarouselImgCount">
#  <span class="js-spnImgNum">1</span> / <span class="js-spnImgCount">12</span>
#  </div>
#  <div class="galleryControl">
#  <button class="imageCarouselLeftContainer" type="button">
#  <i class="imageCarouselArrowLeftIcon"></i>
#  </button>
#  <button class="imageCarouselRightContainer" type="button">
#  <i class="imageCarouselArrowRightIcon"></i>
#  </button>
#  </div>
#  <div class="imageContainer carousel slide" data-interval="false">
#  <div class="carouselSpinner">
#  <i class="aptsLogoMarkIcon rotate"></i>
#  </div>
#  <div class="fallbackSpinner">
#  <i class="spinner"></i>
#  </div>
#  <div class="carouselInner">
#  <div class="item active " data-image="https://images1.apartments.com/i2/F4fOJUOsWLhKkAWxoXQlwsFq5GDjZ0CifzZ8W5vnbig/111/harrison-glendale-ca-building-photo.jpg" title="Building Photo - Harrison">
#  </div>
#  </div>
#  </div>
#  <div class="placardBanner">
#  </div>
#  </div>
#  <div class="propertyInfo">
#  <div class="infoPadding">
#  <div class="freshnessAndFavoritesWrapper">
#  <span class="listingFreshness">
#  <span class="lastUpdated">
#  <i class="clockIcon" title="Last Updated"></i>
#  <span>2 hrs</span>
#  </span>
#  </span>
#  <a class="favoriteIcon neutral" data-liked-classes="liked" data-neutral-classes="neutral" href="javascript:void(0);"></a> </div>
#  <div class="apartmentRentRollupContainer">
#  <span class="altRentDisplay">$1,870 - 3,735</span>
#  <span class="unitLabel ">Studio - 2 Bed</span>
#  <span class="availabilityDisplay noBedSelected ">Available Now</span>
#  </div>
#  <ul class="amenities">
#  <li class="petIcon" title="Dogs"></li>
#  <li class="catIcon" title="Cats"></li>
#  <li class="carIcon" title="Parking"></li>
#  </ul>
#  <div class="contactInfo ">
#  <div class="phone">
#  <i class="phoneIcon"></i>
#  <span>844-832-5691</span>
#  </div>
#  </div>
#  <button class="checkAvailability" data-lang="en" title="Get more information about Harrison">
#  <i class="emailIcon"></i>
#  <span class="label">Email Property</span>
#  <span class="shortLabel">Email</span>
#  </button>
#  </div>
#  </div>
#  </section>
#  </article>
#  </li>
#  <li>
#  <article class="diamond placard" data-ck="k17ten8" data-listingid="ryvgzs0" data-url="https://www.apartments.com/torrey-villas-apartment-homes-san-diego-ca/ryvgzs0/">
#  <header class="placardHeader">
#  <a class="placardTitle js-placardTitle " href="https://www.apartments.com/torrey-villas-apartment-homes-san-diego-ca/ryvgzs0/" title="Torrey Villas Apartment Homes, San Diego, CA">
#  Torrey Villas Apartment Homes</a>
#  <img alt="The Irvine Company" class="propertyLogo" src="https://images1.apartments.com/i2/ovYIo-EfbZiGKJ3uxWJKCnAIxXbsC0EENUiVJMlXqQk/110/the-irvine-company-logo.png"/>
#  <div class="location" title="11100 Vista Sorrento Pkwy, San Diego, CA 92130">11100 Vista Sorrento Pkwy, San Diego, CA 92130</div>
#  </header>
#  <section class="placardContent">
#  <div class="media">
#  <div class="placardCarouselImgCount">
#  <span class="js-spnImgNum">1</span> / <span class="js-spnImgCount">20</span>
#  </div>
#  <div class="galleryControl">
#  <button class="imageCarouselLeftContainer" type="button">
#  <i class="imageCarouselArrowLeftIcon"></i>
#  </button>
#  <button class="imageCarouselRightContainer" type="button">
#  <i class="imageCarouselArrowRightIcon"></i>
#  </button>
#  </div>
#  <div class="imageContainer carousel slide" data-interval="false">
#  <div class="carouselSpinner">
#  <i class="aptsLogoMarkIcon rotate"></i>
#  </div>
#  <div class="fallbackSpinner">
#  <i class="spinner"></i>
#  </div>
#  <div class="carouselInner">
#  <div class="item active " data-image="https://images1.apartments.com/i2/ycZblr_jqhTfgEMfpFKD3ZB2b8hVrjHdtfjaH7d44VA/111/torrey-villas-apartment-homes-san-diego-ca-building-photo.jpg" title="Building Photo - Torrey Villas Apartment Homes">
#  </div>
#  </div>
#  </div>
#  <div class="placardBanner">
#  </div>
#  </div>
#  <div class="propertyInfo">
#  <div class="infoPadding">
#  <div class="freshnessAndFavoritesWrapper">
#  <span class="listingFreshness">
#  <span class="new">
#  <i class="alertLightningBoltIcon" title="New"></i>
#  <span>New</span>
#  </span>
#  </span>
#  <a class="favoriteIcon neutral" data-liked-classes="liked" data-neutral-classes="neutral" href="javascript:void(0);"></a> </div>
#  <div class="apartmentRentRollupContainer">
#  <span class="altRentDisplay">$2,390 - 6,070</span>
#  <span class="unitLabel ">1-3 Bed</span>
#  <span class="availabilityDisplay noBedSelected ">Available Now</span>
#  </div>
#  <ul class="amenities">
#  <li class="petIcon" title="Dogs"></li>
#  <li class="catIcon" title="Cats"></li>
#  <li class="airConditionerIcon" title="Air Conditioning"></li>
#  <li class="laundryIcon" title="Washer/Dryer"></li>
#  <li class="carIcon" title="Parking"></li>
#  </ul>
#  <div class="contactInfo ">
#  <div class="phone">
#  <i class="phoneIcon"></i>
#  <span>844-414-0026</span>
#  </div>
#  </div>
#  <button class="checkAvailability" data-lang="en" title="Get more information about Torrey Villas Apartment Homes">
#  <i class="emailIcon"></i>
#  <span class="label">Email Property</span>
#  <span class="shortLabel">Email</span>
#  </button>
#  </div>
#  </div>
#  </section>
#  </article>
#  </li>
#  <li>
#  <article class="diamond placard" data-ck="k14nn0c" data-listingid="6xxstbs" data-url="https://www.apartments.com/avalon-san-bruno-san-bruno-ca/6xxstbs/">
#  <header class="placardHeader">
#  <a class="placardTitle js-placardTitle " href="https://www.apartments.com/avalon-san-bruno-san-bruno-ca/6xxstbs/" title="Avalon San Bruno, San Bruno, CA">
#  Avalon San Bruno</a>
#  <img alt="AvalonBay Communities, Inc." class="propertyLogo" src="https://images1.apartments.com/i2/S4O4EKtALUg8kfSe0Z6Ym9k7SiflsYgeA7dkjaIVmhs/110/avalonbay-communities-inc-logo.png"/>
#  <div class="location" title="1099 Admiral Ct, San Bruno, CA 94066">1099 Admiral Ct, San Bruno, CA 94066</div>
#  </header>
#  <section class="placardContent">
#  <div class="media">
#  <div class="placardCarouselImgCount">
#  <span class="js-spnImgNum">1</span> / <span class="js-spnImgCount">41</span>
#  </div>
#  <div class="galleryControl">
#  <button class="imageCarouselLeftContainer" type="button">
#  <i class="imageCarouselArrowLeftIcon"></i>
#  </button>
#  <button class="imageCarouselRightContainer" type="button">
#  <i class="imageCarouselArrowRightIcon"></i>
#  </button>
#  </div>
#  <div class="imageContainer carousel slide" data-interval="false">
#  <div class="carouselSpinner">
#  <i class="aptsLogoMarkIcon rotate"></i>
#  </div>
#  <div class="fallbackSpinner">
#  <i class="spinner"></i>
#  </div>
#  <div class="carouselInner">
#  <div class="item active " data-image="https://images1.apartments.com/i2/aWHHx0O6mT0XD1DXwjyo57hkRcvxGTQxC35HYoouRuE/111/avalon-san-bruno-san-bruno-ca-kitchen-with-stainless-steel-appliances-.jpg" title="Kitchen with Stainless Steel Appliances and Hard Surface Vinyl Plank Flooring - Avalon San Bruno">
#  </div>
#  </div>
#  </div>
#  <div class="placardBanner">
#  <button class="virtualTour" title="See Avalon San Bruno in 3D" type="button">
#  <i class="threeDIcon"></i>
#  </button>
#  </div>
#  </div>
#  <div class="propertyInfo">
#  <div class="infoPadding">
#  <div class="freshnessAndFavoritesWrapper">
#  <span class="listingFreshness">
#  <span class="new">
#  <i class="alertLightningBoltIcon" title="New"></i>
#  <span>New</span>
#  </span>
#  </span>
#  <a class="favoriteIcon neutral" data-liked-classes="liked" data-neutral-classes="neutral" href="javascript:void(0);"></a> </div>
#  <div class="apartmentRentRollupContainer">
#  <span class="altRentDisplay">$2,775 - 6,220</span>
#  <span class="unitLabel ">1-3 Bed</span>
#  <span class="availabilityDisplay noBedSelected ">Available Now</span>
#  </div>
#  <ul class="amenities">
#  <li class="petIcon" title="Dogs"></li>
#  <li class="catIcon" title="Cats"></li>
#  <li class="airConditionerIcon" title="Air Conditioning"></li>
#  <li class="laundryIcon" title="Washer/Dryer"></li>
#  <li class="dishWasherIcon" title="Dishwasher"></li>
#  </ul>
#  <div class="contactInfo ">
#  <div class="phone">
#  <i class="phoneIcon"></i>
#  <span>844-541-5754</span>
#  </div>
#  </div>
#  <button class="checkAvailability" data-lang="en" title="Get more information about Avalon San Bruno">
#  <i class="emailIcon"></i>
#  <span class="label">Email Property</span>
#  <span class="shortLabel">Email</span>
#  </button>
#  </div>
#  </div>
#  </section>
#  </article>
#  </li>
#  <li>
#  <article class="diamond placard" data-ck="4km40mj" data-listingid="8w3hm12" data-url="https://www.apartments.com/the-verandas-west-covina-ca/8w3hm12/">
#  <header class="placardHeader">
#  <a class="placardTitle js-placardTitle " href="https://www.apartments.com/the-verandas-west-covina-ca/8w3hm12/" title="The Verandas, West Covina, CA">
#  The Verandas</a>
#  <img alt="Legacy Partners" class="propertyLogo" src="https://images1.apartments.com/i2/1WIEUOHvoG0DcAJ_i5NrQbkY51sz3zDmWnBXK208qww/110/legacy-partners-logo.png"/>
#  <div class="location" title="200 N Grand Ave, West Covina, CA 91791">200 N Grand Ave, West Covina, CA 91791</div>
#  </header>
#  <section class="placardContent">
#  <div class="media">
#  <div class="placardCarouselImgCount">
#  <span class="js-spnImgNum">1</span> / <span class="js-spnImgCount">25</span>
#  </div>
#  <div class="galleryControl">
#  <button class="imageCarouselLeftContainer" type="button">
#  <i class="imageCarouselArrowLeftIcon"></i>
#  </button>
#  <button class="imageCarouselRightContainer" type="button">
#  <i class="imageCarouselArrowRightIcon"></i>
#  </button>
#  </div>
#  <div class="imageContainer carousel slide" data-interval="false">
#  <div class="carouselSpinner">
#  <i class="aptsLogoMarkIcon rotate"></i>
#  </div>
#  <div class="fallbackSpinner">
#  <i class="spinner"></i>
#  </div>
#  <div class="carouselInner">
#  <div class="item active " data-image="https://images1.apartments.com/i2/t7Kq7sWunptPb2vcGpYPKiBKlqJhnLEUD_KBFGPXDnk/111/the-verandas-west-covina-ca-building-photo.jpg" title="Building Photo - The Verandas">
#  </div>
#  </div>
#  </div>
#  <div class="placardBanner">
#  <button class="videoPlay" data-video="https://s.lnimg.com/video/play/SEE6fXl5A" title="Watch The Verandas Video" type="button">
#  <i class="playVideoPlacardIcon"></i>
#  </button>
#  <button class="virtualTour" title="See The Verandas in 3D" type="button">
#  <i class="threeDIcon"></i>
#  </button>
#  </div>
#  </div>
#  <div class="propertyInfo">
#  <div class="infoPadding">
#  <div class="freshnessAndFavoritesWrapper">
#  <span class="listingFreshness">
#  <span class="new">
#  <i class="alertLightningBoltIcon" title="New"></i>
#  <span>New</span>
#  </span>
#  </span>
#  <a class="favoriteIcon neutral" data-liked-classes="liked" data-neutral-classes="neutral" href="javascript:void(0);"></a> </div>
#  <div class="apartmentRentRollupContainer">
#  <span class="altRentDisplay">$1,730 - 2,995</span>
#  <span class="unitLabel ">1-3 Bed</span>
#  <span class="availabilityDisplay noBedSelected ">Available Now</span>
#  </div>
#  <ul class="amenities">
#  <li class="petIcon" title="Dogs"></li>
#  <li class="catIcon" title="Cats"></li>
#  <li class="carIcon" title="Parking"></li>
#  <li class="fitnessIcon" title="Fitness Center"></li>
#  </ul>
#  <div class="contactInfo ">
#  <div class="phone">
#  <i class="phoneIcon"></i>
#  <span>877-252-4188</span>
#  </div>
#  </div>
#  <button class="checkAvailability" data-lang="en" title="Get more information about The Verandas">
#  <i class="emailIcon"></i>
#  <span class="label">Email Property</span>
#  <span class="shortLabel">Email</span>
#  </button>
#  </div>
#  </div>
#  </section>
#  </article>
#  </li>
#  <li>
#  <article class="diamond placard" data-ck="ekyrl9p" data-listingid="5zh5fjm" data-url="https://www.apartments.com/kirker-creek-pittsburg-ca/5zh5fjm/">
#  <header class="placardHeader">
#  <a class="placardTitle js-placardTitle " href="https://www.apartments.com/kirker-creek-pittsburg-ca/5zh5fjm/" title="Kirker Creek, Pittsburg, CA">
#  Kirker Creek</a>
#  <img alt="FPI Management" class="propertyLogo" src="https://images1.apartments.com/i2/1xOKZj7FniwXJ6buHSZxzG9gi1Qutx3JAn3or0Iod2Q/110/fpi-management-logo.png"/>
#  <div class="location" title="1000 Pheasant Dr, Pittsburg, CA 94565">1000 Pheasant Dr, Pittsburg, CA 94565</div>
#  </header>
#  <section class="placardContent">
#  <div class="media">
#  <div class="placardCarouselImgCount">
#  <span class="js-spnImgNum">1</span> / <span class="js-spnImgCount">92</span>
#  </div>
#  <div class="galleryControl">
#  <button class="imageCarouselLeftContainer" type="button">
#  <i class="imageCarouselArrowLeftIcon"></i>
#  </button>
#  <button class="imageCarouselRightContainer" type="button">
#  <i class="imageCarouselArrowRightIcon"></i>
#  </button>
#  </div>
#  <div class="imageContainer carousel slide" data-interval="false">
#  <div class="carouselSpinner">
#  <i class="aptsLogoMarkIcon rotate"></i>
#  </div>
#  <div class="fallbackSpinner">
#  <i class="spinner"></i>
#  </div>
#  <div class="carouselInner">
#  <div class="item active " data-image="https://images1.apartments.com/i2/HxxXxnC6Jv6GAScZfG2JcDrMJPDozlqwsBMAADF0jgs/111/kirker-creek-pittsburg-ca-building-photo.jpg" title="Building Photo - Kirker Creek">
#  </div>
#  </div>
#  </div>
#  <div class="placardBanner">
#  <button class="videoPlay" data-video="https://s.lnimg.com/video/play/DUh2dna3w" title="Watch Kirker Creek Video" type="button">
#  <i class="playVideoPlacardIcon"></i>
#  </button>
#  <button class="virtualTour" title="See Kirker Creek in 3D" type="button">
#  <i class="threeDIcon"></i>
#  </button>
#  </div>
#  </div>
#  <div class="propertyInfo">
#  <div class="infoPadding">
#  <div class="freshnessAndFavoritesWrapper">
#  <span class="listingFreshness">
#  <span class="new">
#  <i class="alertLightningBoltIcon" title="New"></i>
#  <span>New</span>
#  </span>
#  </span>
#  <a class="favoriteIcon neutral" data-liked-classes="liked" data-neutral-classes="neutral" href="javascript:void(0);"></a> </div>
#  <div class="apartmentRentRollupContainer">
#  <span class="altRentDisplay">$1,742 - 8,732</span>
#  <span class="unitLabel ">1-2 Bed</span>
#  <span class="availabilityDisplay noBedSelected ">Available Now</span>
#  </div>
#  <ul class="amenities">
#  <li class="petIcon" title="Dogs"></li>
#  <li class="catIcon" title="Cats"></li>
#  <li class="airConditionerIcon" title="Air Conditioning"></li>
#  <li class="laundryIcon" title="Washer/Dryer"></li>
#  <li class="dishWasherIcon" title="Dishwasher"></li>
#  </ul>
#  <div class="contactInfo ">
#  <div class="phone">
#  <i class="phoneIcon"></i>
#  <span>877-737-1601</span>
#  </div>
#  </div>
#  <button class="checkAvailability" data-lang="en" title="Get more information about Kirker Creek">
#  <i class="emailIcon"></i>
#  <span class="label">Email Property</span>
#  <span class="shortLabel">Email</span>
#  </button>
#  </div>
#  </div>
#  </section>
#  </article>
#  </li>
#  <li>
#  <article class="diamond placard" data-ck="f6m6qyv" data-listingid="h1295y2" data-url="https://www.apartments.com/pepperwood-knoll-apartments-sacramento-ca/h1295y2/">
#  <header class="placardHeader">
#  <a class="placardTitle js-placardTitle " href="https://www.apartments.com/pepperwood-knoll-apartments-sacramento-ca/h1295y2/" title="Pepperwood Knoll Apartments, Sacramento, CA">
#  Pepperwood Knoll Apartments</a>
#  <img alt="JMK Investments, Inc." class="propertyLogo" src="https://images1.apartments.com/i2/P02w4jo73m2_-TRDEPd7dj-Lzt5pH0C1i3mRiAFTASw/110/jmk-investments-inc-logo.png"/>
#  <div class="location" title="7200 Pepperwood Knoll Ln, Sacramento, CA 95842">7200 Pepperwood Knoll Ln, Sacramento, CA 95842</div>
#  </header>
#  <section class="placardContent">
#  <div class="media">
#  <div class="placardCarouselImgCount">
#  <span class="js-spnImgNum">1</span> / <span class="js-spnImgCount">19</span>
#  </div>
#  <div class="galleryControl">
#  <button class="imageCarouselLeftContainer" type="button">
#  <i class="imageCarouselArrowLeftIcon"></i>
#  </button>
#  <button class="imageCarouselRightContainer" type="button">
#  <i class="imageCarouselArrowRightIcon"></i>
#  </button>
#  </div>
#  <div class="imageContainer carousel slide" data-interval="false">
#  <div class="carouselSpinner">
#  <i class="aptsLogoMarkIcon rotate"></i>
#  </div>
#  <div class="fallbackSpinner">
#  <i class="spinner"></i>
#  </div>
#  <div class="carouselInner">
#  <div class="item active " data-image="https://images1.apartments.com/i2/xIjlv_KfF4B2yvgmCKxhMrBXkTY-7g33y5qnm6KRpxA/111/pepperwood-knoll-apartments-sacramento-ca-building-photo.jpg" title="Building Photo - Pepperwood Knoll Apartments">
#  </div>
#  </div>
#  </div>
#  <div class="placardBanner">
#  <button class="videoPlay" data-video="https://s.lnimg.com/video/play/Fim8xbB1Q" title="Watch Pepperwood Knoll Apartments Video" type="button">
#  <i class="playVideoPlacardIcon"></i>
#  </button>
#  <button class="virtualTour" title="See Pepperwood Knoll Apartments in 3D" type="button">
#  <i class="threeDIcon"></i>
#  </button>
#  </div>
#  </div>
#  <div class="propertyInfo">
#  <div class="infoPadding">
#  <div class="freshnessAndFavoritesWrapper">
#  <span class="listingFreshness">
#  <span class="lastUpdated">
#  <i class="clockIcon" title="Last Updated"></i>
#  <span>1 wk</span>
#  </span>
#  </span>
#  <a class="favoriteIcon neutral" data-liked-classes="liked" data-neutral-classes="neutral" href="javascript:void(0);"></a> </div>
#  <div class="apartmentRentRollupContainer">
#  <span class="altRentDisplay">$1,095 - 1,425</span>
#  <span class="unitLabel ">1-2 Bed</span>
#  <span class="availabilityDisplay noBedSelected ">Available 08/21/18</span>
#  </div>
#  <ul class="amenities">
#  <li class="petIcon" title="Dogs"></li>
#  <li class="catIcon" title="Cats"></li>
#  <li class="airConditionerIcon" title="Air Conditioning"></li>
#  <li class="laundryIcon" title="Washer/Dryer"></li>
#  <li class="dishWasherIcon" title="Dishwasher"></li>
#  </ul>
#  <div class="contactInfo ">
#  <div class="phone">
#  <i class="phoneIcon"></i>
#  <span>844-381-2656</span>
#  </div>
#  </div>
#  <button class="checkAvailability" data-lang="en" title="Get more information about Pepperwood Knoll Apartments">
#  <i class="emailIcon"></i>
#  <span class="label">Email Property</span>
#  <span class="shortLabel">Email</span>
#  </button>
#  </div>
#  </div>
#  </section>
#  </article>
#  </li>
#  <li>
#  <article class="diamond placard" data-ck="k14nn0c" data-listingid="4wgqwzh" data-url="https://www.apartments.com/eaves-san-marcos-san-marcos-ca/4wgqwzh/">
#  <header class="placardHeader">
#  <a class="placardTitle js-placardTitle " href="https://www.apartments.com/eaves-san-marcos-san-marcos-ca/4wgqwzh/" title="eaves San Marcos, San Marcos, CA">
#  eaves San Marcos</a>
#  <img alt="AvalonBay Communities, Inc." class="propertyLogo" src="https://images1.apartments.com/i2/PkyoptFgxl84DWk1rtREUhCHUbvoT5bbV4YRrhLEA8E/110/avalonbay-communities-inc-logo.png"/>
#  <div class="location" title="823 Nordahl Rd, San Marcos, CA 92069">823 Nordahl Rd, San Marcos, CA 92069</div>
#  </header>
#  <section class="placardContent">
#  <div class="media">
#  <div class="placardCarouselImgCount">
#  <span class="js-spnImgNum">1</span> / <span class="js-spnImgCount">51</span>
#  </div>
#  <div class="galleryControl">
#  <button class="imageCarouselLeftContainer" type="button">
#  <i class="imageCarouselArrowLeftIcon"></i>
#  </button>
#  <button class="imageCarouselRightContainer" type="button">
#  <i class="imageCarouselArrowRightIcon"></i>
#  </button>
#  </div>
#  <div class="imageContainer carousel slide" data-interval="false">
#  <div class="carouselSpinner">
#  <i class="aptsLogoMarkIcon rotate"></i>
#  </div>
#  <div class="fallbackSpinner">
#  <i class="spinner"></i>
#  </div>
#  <div class="carouselInner">
#  <div class="item active " data-image="https://images1.apartments.com/i2/WovfQjaUF0xJWHI1BTB_UkG-zHA5S_WdX55EYeX-T0M/111/eaves-san-marcos-san-marcos-ca-building-photo.jpg" title="Building Photo - eaves San Marcos">
#  </div>
#  </div>
#  </div>
#  <div class="placardBanner">
#  </div>
#  </div>
#  <div class="propertyInfo">
#  <div class="infoPadding">
#  <div class="freshnessAndFavoritesWrapper">
#  <span class="listingFreshness">
#  <span class="lastUpdated">
#  <i class="clockIcon" title="Last Updated"></i>
#  <span>1 day</span>
#  </span>
#  </span>
#  <a class="favoriteIcon neutral" data-liked-classes="liked" data-neutral-classes="neutral" href="javascript:void(0);"></a> </div>
#  <div class="apartmentRentRollupContainer">
#  <span class="altRentDisplay">$1,785 - 2,770</span>
#  <span class="unitLabel ">1-3 Bed</span>
#  <span class="availabilityDisplay noBedSelected ">Available Now</span>
#  </div>
#  <ul class="amenities">
#  <li class="petIcon" title="Dogs"></li>
#  <li class="catIcon" title="Cats"></li>
#  <li class="airConditionerIcon" title="Air Conditioning"></li>
#  <li class="laundryIcon" title="Washer/Dryer"></li>
#  <li class="carIcon" title="Parking"></li>
#  </ul>
#  <div class="contactInfo ">
#  <div class="phone">
#  <i class="phoneIcon"></i>
#  <span>844-760-5918</span>
#  </div>
#  </div>
#  <button class="checkAvailability" data-lang="en" title="Get more information about eaves San Marcos">
#  <i class="emailIcon"></i>
#  <span class="label">Email Property</span>
#  <span class="shortLabel">Email</span>
#  </button>
#  </div>
#  </div>
#  </section>
#  </article>
#  </li>
#  <li>
#  <article class="diamond placard" data-ck="ge67wew" data-listingid="h80fqb0" data-url="https://www.apartments.com/hensley-at-corona-pointe-apartments-corona-ca/h80fqb0/">
#  <header class="placardHeader">
#  <a class="placardTitle js-placardTitle " href="https://www.apartments.com/hensley-at-corona-pointe-apartments-corona-ca/h80fqb0/" title="Hensley at Corona Pointe Apartments, Corona, CA">
#  Hensley at Corona Pointe Apartments</a>
#  <img alt="Fairfield Residential" class="propertyLogo" src="https://images1.apartments.com/i2/C_Vpm30cEUcoy2RzXXVp-_Ux8rdXdzfJWJnaS36O9QA/110/fairfield-residential-logo.png"/>
#  <div class="location" title="1171 E Baywood Dr, Corona, CA 92881">1171 E Baywood Dr, Corona, CA 92881</div>
#  </header>
#  <section class="placardContent">
#  <div class="media">
#  <div class="placardCarouselImgCount">
#  <span class="js-spnImgNum">1</span> / <span class="js-spnImgCount">25</span>
#  </div>
#  <div class="galleryControl">
#  <button class="imageCarouselLeftContainer" type="button">
#  <i class="imageCarouselArrowLeftIcon"></i>
#  </button>
#  <button class="imageCarouselRightContainer" type="button">
#  <i class="imageCarouselArrowRightIcon"></i>
#  </button>
#  </div>
#  <div class="imageContainer carousel slide" data-interval="false">
#  <div class="carouselSpinner">
#  <i class="aptsLogoMarkIcon rotate"></i>
#  </div>
#  <div class="fallbackSpinner">
#  <i class="spinner"></i>
#  </div>
#  <div class="carouselInner">
#  <div class="item active " data-image="https://images1.apartments.com/i2/osHTlH82iMENA_CErsYfbJbGsr05rseOKJr5KAeDk20/111/hensley-at-corona-pointe-apartments-corona-ca-building-photo.jpg" title="Building Photo - Hensley at Corona Pointe Apartments">
#  </div>
#  </div>
#  </div>
#  <div class="placardBanner">
#  <button class="videoPlay" data-video="https://s.lnimg.com/video/play/RGl6Xrx5w" title="Watch Hensley at Corona Pointe Apartments Video" type="button">
#  <i class="playVideoPlacardIcon"></i>
#  </button>
#  <button class="virtualTour" title="See Hensley at Corona Pointe Apartments in 3D" type="button">
#  <i class="threeDIcon"></i>
#  </button>
#  </div>
#  </div>
#  <div class="propertyInfo">
#  <div class="infoPadding">
#  <div class="freshnessAndFavoritesWrapper">
#  <span class="listingFreshness">
#  <span class="lastUpdated">
#  <i class="clockIcon" title="Last Updated"></i>
#  <span>2 hrs</span>
#  </span>
#  </span>
#  <a class="favoriteIcon neutral" data-liked-classes="liked" data-neutral-classes="neutral" href="javascript:void(0);"></a> </div>
# ...
#  The Timbers Apartments</a>
#  <img alt="Petree Timbers Inc" class="propertyLogo" src="https://images1.apartments.com/i2/Ul1_Kh-J7Vt3RxgaagKD0J7m0u8k9kibaddkc22mIJU/110/petree-timbers-inc-logo.png"/>
#  <div class="location" title="1110 Petree St, El Cajon, CA 92020">1110 Petree St, El Cajon, CA 92020</div>
#  </header>
#  <section class="placardContent">
#  <div class="media">
#  <div class="placardCarouselImgCount">
#  <span class="js-spnImgNum">1</span> / <span class="js-spnImgCount">91</span>
#  </div>
#  <div class="galleryControl">
#  <button class="imageCarouselLeftContainer" type="button">
#  <i class="imageCarouselArrowLeftIcon"></i>
#  </button>
#  <button class="imageCarouselRightContainer" type="button">
#  <i class="imageCarouselArrowRightIcon"></i>
#  </button>
#  </div>
#  <div class="imageContainer carousel slide" data-interval="false">
#  <div class="carouselSpinner">
#  <i class="aptsLogoMarkIcon rotate"></i>
#  </div>
#  <div class="fallbackSpinner">
#  <i class="spinner"></i>
#  </div>
#  <div class="carouselInner">
#  <div class="item active " data-image="https://images1.apartments.com/i2/C7UaIRiZBMI9X7PjXPJAzMxYCdMbz6WQd-ePqMmoh18/111/the-timbers-apartments-el-cajon-ca-building-photo.jpg" title="Building Photo - The Timbers Apartments">
#  </div>
#  </div>
#  </div>
#  <div class="placardBanner">
#  <button class="virtualTour" title="See The Timbers Apartments in 3D" type="button">
#  <i class="threeDIcon"></i>
#  </button>
#  </div>
#  </div>
#  <div class="propertyInfo">
#  <div class="infoPadding">
#  <div class="freshnessAndFavoritesWrapper">
#  <span class="listingFreshness">
#  <span class="lastUpdated">
#  <i class="clockIcon" title="Last Updated"></i>
#  <span>1 day</span>
#  </span>
#  </span>
#  <a class="favoriteIcon neutral" data-liked-classes="liked" data-neutral-classes="neutral" href="javascript:void(0);"></a> </div>
#  <div class="apartmentRentRollupContainer">
#  <span class="altRentDisplay">$1,430</span>
#  <span class="unitLabel ">1 Bed</span>
#  <span class="availabilityDisplay noBedSelected ">Available 08/23/18</span>
#  </div>
#  <ul class="amenities">
#  <li class="petIcon" title="Dogs"></li>
#  <li class="catIcon" title="Cats"></li>
#  <li class="airConditionerIcon" title="Air Conditioning"></li>
#  <li class="dishWasherIcon" title="Dishwasher"></li>
#  <li class="carIcon" title="Parking"></li>
#  </ul>
#  <div class="contactInfo ">
#  <div class="phone">
#  <i class="phoneIcon"></i>
#  <span>888-817-0724</span>
#  </div>
#  </div>
#  <button class="checkAvailability" data-lang="en" title="Get more information about The Timbers Apartments">
#  <i class="emailIcon"></i>
#  <span class="label">Email Property</span>
#  <span class="shortLabel">Email</span>
#  </button>
#  </div>
#  </div>
#  </section>
#  </article>
#  </li>
#  <li>
#  <article class="diamond placard" data-ck="f6m6qyv" data-listingid="y078b3r" data-url="https://www.apartments.com/greenridge-apartments-sacramento-ca/y078b3r/">
#  <header class="placardHeader">
#  <a class="placardTitle js-placardTitle " href="https://www.apartments.com/greenridge-apartments-sacramento-ca/y078b3r/" title="Greenridge Apartments, Sacramento, CA">
#  Greenridge Apartments</a>
#  <img alt="JMK Investments, Inc." class="propertyLogo" src="https://images1.apartments.com/i2/P02w4jo73m2_-TRDEPd7dj-Lzt5pH0C1i3mRiAFTASw/110/jmk-investments-inc-logo.png"/>
#  <div class="location" title="5351 47th Ave, Sacramento, CA 95824">5351 47th Ave, Sacramento, CA 95824</div>
#  </header>
#  <section class="placardContent">
#  <div class="media">
#  <div class="placardCarouselImgCount">
#  <span class="js-spnImgNum">1</span> / <span class="js-spnImgCount">3</span>
#  </div>
#  <div class="galleryControl">
#  <button class="imageCarouselLeftContainer" type="button">
#  <i class="imageCarouselArrowLeftIcon"></i>
#  </button>
#  <button class="imageCarouselRightContainer" type="button">
#  <i class="imageCarouselArrowRightIcon"></i>
#  </button>
#  </div>
#  <div class="imageContainer carousel slide" data-interval="false">
#  <div class="carouselSpinner">
#  <i class="aptsLogoMarkIcon rotate"></i>
#  </div>
#  <div class="fallbackSpinner">
#  <i class="spinner"></i>
#  </div>
#  <div class="carouselInner">
#  <div class="item active " data-image="https://images1.apartments.com/i2/_mpsIEYZ7j1Rj_I3JDNyzRH84K7QD9Je9WMQ-nt24yg/111/greenridge-apartments-sacramento-ca-building-photo.jpg" title="Building Photo - Greenridge Apartments">
#  </div>
#  </div>
#  </div>
#  <div class="placardBanner">
#  <button class="videoPlay" data-video="https://s.lnimg.com/video/play/Whj480f2g" title="Watch Greenridge Apartments Video" type="button">
#  <i class="playVideoPlacardIcon"></i>
#  </button>
#  <button class="virtualTour" title="See Greenridge Apartments in 3D" type="button">
#  <i class="threeDIcon"></i>
#  </button>
#  </div>
#  </div>
#  <div class="propertyInfo">
#  <div class="infoPadding">
#  <div class="freshnessAndFavoritesWrapper">
#  <span class="listingFreshness">
#  <span class="lastUpdated">
#  <i class="clockIcon" title="Last Updated"></i>
#  <span>2 wks</span>
#  </span>
#  </span>
#  <a class="favoriteIcon neutral" data-liked-classes="liked" data-neutral-classes="neutral" href="javascript:void(0);"></a> </div>
#  <div class="apartmentRentRollupContainer">
#  <span class="altRentDisplay">$990 - 1,075</span>
#  <span class="unitLabel ">1-2 Bed</span>
#  <span class="availabilityDisplay noBedSelected ">Available Soon</span>
#  </div>
#  <ul class="amenities">
#  <li class="petIcon" title="Dogs"></li>
#  <li class="catIcon" title="Cats"></li>
#  <li class="airConditionerIcon" title="Air Conditioning"></li>
#  <li class="dishWasherIcon" title="Dishwasher"></li>
#  <li class="carIcon" title="Parking"></li>
#  </ul>
#  <div class="contactInfo ">
#  <div class="phone">
#  <i class="phoneIcon"></i>
#  <span>844-223-1792</span>
#  </div>
#  </div>
#  <button class="checkAvailability" data-lang="en" title="Get more information about Greenridge Apartments">
#  <i class="emailIcon"></i>
#  <span class="label">Email Property</span>
#  <span class="shortLabel">Email</span>
#  </button>
#  </div>
#  </div>
#  </section>
#  </article>
#  </li>
#  <li>
#  <article class="diamond placard" data-ck="mwlfs3j" data-listingid="0yfzfd0" data-url="https://www.apartments.com/portofino-apartments-temecula-ca/0yfzfd0/">
#  <header class="placardHeader">
#  <a class="placardTitle js-placardTitle " href="https://www.apartments.com/portofino-apartments-temecula-ca/0yfzfd0/" title="Portofino Apartments, Temecula, CA">
#  Portofino Apartments</a>
#  <img alt="Cannon Management" class="propertyLogo" src="https://images1.apartments.com/i2/tkVX6iQQWsfyAkb-2Tph107VGjrcjlkz5Etit881Bqc/110/cannon-management-logo.png"/>
#  <div class="location" title="30000 Rancho California Rd, Temecula, CA 92591">30000 Rancho California Rd, Temecula, CA 92591</div>
#  </header>
#  <section class="placardContent">
#  <div class="media">
#  <div class="placardCarouselImgCount">
#  <span class="js-spnImgNum">1</span> / <span class="js-spnImgCount">12</span>
#  </div>
#  <div class="galleryControl">
#  <button class="imageCarouselLeftContainer" type="button">
#  <i class="imageCarouselArrowLeftIcon"></i>
#  </button>
#  <button class="imageCarouselRightContainer" type="button">
#  <i class="imageCarouselArrowRightIcon"></i>
#  </button>
#  </div>
#  <div class="imageContainer carousel slide" data-interval="false">
#  <div class="carouselSpinner">
#  <i class="aptsLogoMarkIcon rotate"></i>
#  </div>
#  <div class="fallbackSpinner">
#  <i class="spinner"></i>
#  </div>
#  <div class="carouselInner">
#  <div class="item active " data-image="https://images1.apartments.com/i2/kfClvzYtYcXtLAw-ec3n31C0J10YRvgycGQQ2ne-BGE/111/portofino-apartments-temecula-ca-building-photo.jpg" title="Building Photo - Portofino Apartments">
#  </div>
#  </div>
#  </div>
#  <div class="placardBanner">
#  <button class="videoPlay" data-video="https://s.lnimg.com/video/play/Ag31pz05A" title="Watch Portofino Apartments Video" type="button">
#  <i class="playVideoPlacardIcon"></i>
#  </button>
#  <button class="virtualTour" title="See Portofino Apartments in 3D" type="button">
#  <i class="threeDIcon"></i>
#  </button>
#  </div>
#  </div>
#  <div class="propertyInfo">
#  <div class="infoPadding">
#  <div class="freshnessAndFavoritesWrapper">
#  <span class="listingFreshness">
#  <span class="lastUpdated">
#  <i class="clockIcon" title="Last Updated"></i>
#  <span>2 wks</span>
#  </span>
#  </span>
#  <a class="favoriteIcon neutral" data-liked-classes="liked" data-neutral-classes="neutral" href="javascript:void(0);"></a> </div>
#  <div class="apartmentRentRollupContainer">
#  <span class="altRentDisplay">$1,345 - 2,170</span>
#  <span class="unitLabel ">1-3 Bed</span>
#  <span class="availabilityDisplay noBedSelected ">Available Now</span>
#  </div>
#  <ul class="amenities">
#  <li class="petIcon" title="Dogs"></li>
#  <li class="catIcon" title="Cats"></li>
#  <li class="airConditionerIcon" title="Air Conditioning"></li>
#  <li class="laundryIcon" title="Washer/Dryer"></li>
#  <li class="dishWasherIcon" title="Dishwasher"></li>
#  </ul>
#  <div class="contactInfo ">
#  <div class="phone">
#  <i class="phoneIcon"></i>
#  <span>951-225-1651</span>
#  </div>
#  </div>
#  <button class="checkAvailability" data-lang="en" title="Get more information about Portofino Apartments">
#  <i class="emailIcon"></i>
#  <span class="label">Email Property</span>
#  <span class="shortLabel">Email</span>
#  </button>
#  </div>
#  </div>
#  </section>
#  </article>
#  </li>
#  <li>
#  <article class="diamond placard" data-ck="wc6855k" data-listingid="szlkpb7" data-url="https://www.apartments.com/barclay-square-san-diego-ca/szlkpb7/">
#  <header class="placardHeader">
#  <a class="placardTitle js-placardTitle " href="https://www.apartments.com/barclay-square-san-diego-ca/szlkpb7/" title="Barclay Square, San Diego, CA">
#  Barclay Square</a>
#  <img alt="The ConAm Group of Companies" class="propertyLogo" src="https://images1.apartments.com/i2/QIKP5MqXRUdqxbBRcd2bh6wZRxxVZX5-_fQnfgInTgQ/110/the-conam-group-of-companies-logo.png"/>
#  <div class="location" title="6363 Beadnell Way, San Diego, CA 92117">6363 Beadnell Way, San Diego, CA 92117</div>
#  </header>
#  <section class="placardContent">
#  <div class="media">
#  <div class="placardCarouselImgCount">
#  <span class="js-spnImgNum">1</span> / <span class="js-spnImgCount">29</span>
#  </div>
#  <div class="galleryControl">
#  <button class="imageCarouselLeftContainer" type="button">
#  <i class="imageCarouselArrowLeftIcon"></i>
#  </button>
#  <button class="imageCarouselRightContainer" type="button">
#  <i class="imageCarouselArrowRightIcon"></i>
#  </button>
#  </div>
#  <div class="imageContainer carousel slide" data-interval="false">
#  <div class="carouselSpinner">
#  <i class="aptsLogoMarkIcon rotate"></i>
#  </div>
#  <div class="fallbackSpinner">
#  <i class="spinner"></i>
#  </div>
#  <div class="carouselInner">
#  <div class="item active " data-image="https://images1.apartments.com/i2/gVxUjtyGbwGO3dvqQsfKaL_y4ck87crnBgCT2q_rnMU/111/barclay-square-san-diego-ca-building-photo.jpg" title="Building Photo - Barclay Square">
#  </div>
#  </div>
#  </div>
#  <div class="placardBanner">
#  <button class="videoPlay" data-video="https://s.lnimg.com/video/play/JZE0YTV9w" title="Watch Barclay Square Video" type="button">
#  <i class="playVideoPlacardIcon"></i>
#  </button>
#  <button class="virtualTour" title="See Barclay Square in 3D" type="button">
#  <i class="threeDIcon"></i>
#  </button>
#  </div>
#  </div>
#  <div class="propertyInfo">
#  <div class="infoPadding">
#  <div class="freshnessAndFavoritesWrapper">
#  <span class="listingFreshness">
#  <span class="new">
#  <i class="alertLightningBoltIcon" title="New"></i>
#  <span>New</span>
#  </span>
#  </span>
#  <a class="favoriteIcon neutral" data-liked-classes="liked" data-neutral-classes="neutral" href="javascript:void(0);"></a> </div>
#  <div class="apartmentRentRollupContainer">
#  <span class="altRentDisplay">$1,575 - 2,430</span>
#  <span class="unitLabel ">1-3 Bed</span>
#  <span class="availabilityDisplay noBedSelected ">Available 08/16/18</span>
#  </div>
#  <ul class="amenities">
#  <li class="dishWasherIcon" title="Dishwasher"></li>
#  <li class="carIcon" title="Parking"></li>
#  </ul>
#  <div class="contactInfo ">
#  <div class="phone">
#  <i class="phoneIcon"></i>
#  <span>844-220-7316</span>
#  </div>
#  </div>
#  <button class="checkAvailability" data-lang="en" title="Get more information about Barclay Square">
#  <i class="emailIcon"></i>
#  <span class="label">Email Property</span>
#  <span class="shortLabel">Email</span>
#  </button>
#  </div>
#  </div>
#  </section>
#  </article>
#  </li>
#  <li>
#  <article class="diamond placard" data-ck="24h6w9c" data-listingid="f79btmt" data-url="https://www.apartments.com/windscape-fresno-ca/f79btmt/">
#  <header class="placardHeader">
#  <a class="placardTitle js-placardTitle " href="https://www.apartments.com/windscape-fresno-ca/f79btmt/" title="Windscape, Fresno, CA">
#  Windscape</a>
#  <img alt="San Mar Properties, Inc." class="propertyLogo" src="https://images1.apartments.com/i2/CIVGG4S90QdZpHVRQb0Mazq8ZOaQwZUpgsr3ncytvEo/110/san-mar-properties-inc-logo.png"/>
#  <div class="location" title="373 W Nees Ave, Fresno, CA 93711">373 W Nees Ave, Fresno, CA 93711</div>
#  </header>
#  <section class="placardContent">
#  <div class="media">
#  <div class="placardCarouselImgCount">
#  <span class="js-spnImgNum">1</span> / <span class="js-spnImgCount">60</span>
#  </div>
#  <div class="galleryControl">
#  <button class="imageCarouselLeftContainer" type="button">
#  <i class="imageCarouselArrowLeftIcon"></i>
#  </button>
#  <button class="imageCarouselRightContainer" type="button">
#  <i class="imageCarouselArrowRightIcon"></i>
#  </button>
#  </div>
#  <div class="imageContainer carousel slide" data-interval="false">
#  <div class="carouselSpinner">
#  <i class="aptsLogoMarkIcon rotate"></i>
#  </div>
#  <div class="fallbackSpinner">
#  <i class="spinner"></i>
#  </div>
#  <div class="carouselInner">
#  <div class="item active " data-image="https://images1.apartments.com/i2/FmTcREpdGVKp4kk4gEtYHAu0YmV2klMXgwEW07vMc-A/111/windscape-fresno-ca-building-photo.jpg" title="Building Photo - Windscape">
#  </div>
#  </div>
#  </div>
#  <div class="placardBanner">
#  <button class="virtualTour" title="See Windscape in 3D" type="button">
#  <i class="threeDIcon"></i>
#  </button>
#  </div>
#  </div>
#  <div class="propertyInfo">
#  <div class="infoPadding">
#  <div class="freshnessAndFavoritesWrapper">
#  <span class="listingFreshness">
#  <span class="lastUpdated">
#  <i class="clockIcon" title="Last Updated"></i>
#  <span>2 wks</span>
#  </span>
#  </span>
#  <a class="favoriteIcon neutral" data-liked-classes="liked" data-neutral-classes="neutral" href="javascript:void(0);"></a> </div>
#  <div class="apartmentRentRollupContainer">
#  <span class="altRentDisplay">$960 - 1,215</span>
#  <span class="unitLabel ">1-2 Bed</span>
#  <span class="availabilityDisplay noBedSelected ">Available Now</span>
#  </div>
#  <ul class="amenities">
#  <li class="petIcon" title="Dogs"></li>
#  <li class="catIcon" title="Cats"></li>
#  <li class="airConditionerIcon" title="Air Conditioning"></li>
#  <li class="dishWasherIcon" title="Dishwasher"></li>
#  <li class="carIcon" title="Parking"></li>
#  </ul>
#  <div class="contactInfo ">
#  <div class="phone">
#  <i class="phoneIcon"></i>
#  <span>855-235-7657</span>
#  </div>
#  </div>
#  <button class="checkAvailability" data-lang="en" title="Get more information about Windscape">
#  <i class="emailIcon"></i>
#  <span class="label">Email Property</span>
#  <span class="shortLabel">Email</span>
#  </button>
#  </div>
#  </div>
#  </section>
#  </article>
#  </li> <li>
#  <div class="paging" id="paging">
#  <a class="previous disabled" data-page="0" href="javascript:void(0)">
#  <span class="menuArrowLeftIcon"></span>
#  </a>
#  <a class="active" data-page="1">1</a>
#  <a data-page="2" href="https://www.apartments.com/apartments/los-angeles-ca/2/"> 2</a>
#  <a data-page="3" href="https://www.apartments.com/apartments/los-angeles-ca/3/"> 3</a>
#  <a data-page="4" href="https://www.apartments.com/apartments/los-angeles-ca/4/"> 4</a>
#  <a data-page="5" href="https://www.apartments.com/apartments/los-angeles-ca/5/"> 5</a>
#  <span class="ellipsis">...</span>
#  <a data-page="28" href="https://www.apartments.com/apartments/los-angeles-ca/28/"> 28</a>
#  <a class="next " data-page="2" href="https://www.apartments.com/apartments/los-angeles-ca/2/">
#  <span class="menuArrowRightIcon"></span>
#  </a>
#  </div>
#  </li>
#  </ul>
#  </div>]

# %%
#Set up list to hold response info
link_dict = []
all_property = []

# %%
# Loop through x pages of the website with filter of Single House
for scrape_links in [scrape_link.format(page) for page in range(1,2)]:
    res = requests.get(scrape_links)
    new_soup = BeautifulSoup(res.text, 'html.parser')
    new_results = new_soup.find_all('article', class_="placard")
    
    # Loop through returned results
    for result in new_results:
        find_tag = result.find('a')['href']
        link_dict.append(find_tag)

for property_link in link_dict:
    res = requests.get(property_link)
    new_soup = BeautifulSoup(res.text, 'html.parser')
    new_results = new_soup.find_all('div', class_="mainWrapper")
    
    
    for result in new_results:
        try:
            # Identify and return property name of Rental Place
            property_name = result.find('h1', class_="propertyName")
            # Identify and return address information of Rental Place
            clean_property_name = property_name.text.strip().replace("\n", "")
            street_data = result.find('div', class_="propertyAddress")
            street = street_data.text.strip().replace("\n", "").replace("\r", "")
            street_address = street.split(",")
            city = " ".join(street_address[1].split())
            state = " ".join(street_address[2].split())[:2]
            zip_code = " ".join(street_address[2].split())[2:7]
            # Identify and return number of bedroom and price of Rental Place
            bedroom_container = result.find('div', class_="rentRollupContainer")
            all_the_rents = bedroom_container.findAll('span', class_="rentRollup")
            
            bedroom_info = []
            for rent_block in all_the_rents:
                
                bedroom_type = rent_block.find('span', class_="longText").text
                try:
                    price = re.search('\$.* ', rent_block.text)
                    price = price.group(0)[:2]
                except:
                    price = ""
                
                bedroom_info.append({
                    'bedroom_type': bedroom_type,
                    'price': price
                })
            
            rent_obj = {
                "Property_Name_Rent": clean_property_name,
                "City_Rent": city,
                "Type": "Apartment",
                "State_Rent": state,
                "Zip_code": zip_code,
                "Bedroom_Info": bedroom_info,
                
            }
            
            for item in bedroom_info:
                rent_obj[item["bedroom_type"]] = item["price"]
                

        
            all_property.append(rent_obj)
        except AttributeError as e:
            print(e)

# print(all_property)

# %%
house_data = pd.DataFrame(all_property)
house_data
# Out:
#     1 Bedroom 2 Bedrooms 3 Bedrooms  \
# 0   $1,788 –   $1,819 –   $2,191 –
# 1   $2,372 –   $3,077 –         NaN
# 2   $1,450 –   $1,890 –   $2,160 –
# 3   $2,128 –   $2,986 –         NaN
# 4              $1,085 –         NaN
# 5   $1,600 –   $1,930 –         NaN
# 6   $1,118 –   $1,295 –
# 7   $2,305 –   $2,650 –         NaN
# 8   $2,500 –   $3,050 –         NaN
# 9   $2,390 –   $3,095 –   $3,395 –
# 10  $2,775 –   $3,390 –   $4,405 –
# 11  $1,730 –   $1,900 –   $2,283 –
# 12  $1,742 –   $1,783 –         NaN
# 13             $1,250 –         NaN
# 14  $1,785 –   $2,170 –
# 15  $1,390 –   $1,581 –         NaN
# 16  $1,025 –   $1,095 –         NaN
# 17  $2,365 –   $3,072 –         NaN
# 18  $1,835 –   $2,195 –         NaN
# 19  $1,281 –   $1,558 –         NaN
# 20                   NaN        NaN
# 21                              NaN
# 22  $1,345 –   $1,545 –   $1,995 –
# 23
# 24    $960 –   $1,075 –         NaN
#
#                                          Bedroom_Info         City_Rent  \
# 0   [{'bedroom_type': '1 Bedroom', 'price': '$1,78...          Eastvale
# 1   [{'bedroom_type': 'Studio', 'price': '$1,879 –...       Los Angeles
# 2   [{'bedroom_type': '1 Bedroom', 'price': '$1,45...            Folsom
# 3   [{'bedroom_type': '1 Bedroom', 'price': '$2,12...  Westlake Village
# 4   [{'bedroom_type': '1 Bedroom', 'price': ''}, {...             Hemet
# 5   [{'bedroom_type': '1 Bedroom', 'price': '$1,60...           Anaheim
# 6   [{'bedroom_type': 'Studio', 'price': ''}, {'be...        Sacramento
# 7   [{'bedroom_type': '1 Bedroom', 'price': '$2,30...           Fremont
# 8   [{'bedroom_type': 'Studio', 'price': '$1,870 –...          Glendale
# 9   [{'bedroom_type': '1 Bedroom', 'price': '$2,39...         San Diego
# 10  [{'bedroom_type': '1 Bedroom', 'price': '$2,77...         San Bruno
# 11  [{'bedroom_type': '1 Bedroom', 'price': '$1,73...       West Covina
# 12  [{'bedroom_type': '1 Bedroom', 'price': '$1,74...         Pittsburg
# 13  [{'bedroom_type': '1 Bedroom', 'price': ''}, {...        Sacramento
# 14  [{'bedroom_type': '1 Bedroom', 'price': '$1,78...        San Marcos
# 15  [{'bedroom_type': '1 Bedroom', 'price': '$1,39...            Corona
# 16  [{'bedroom_type': '1 Bedroom', 'price': '$1,02...            Fresno
# 17  [{'bedroom_type': '1 Bedroom', 'price': '$2,36...          Berkeley
# 18  [{'bedroom_type': '1 Bedroom', 'price': '$1,83...      San Clemente
# 19  [{'bedroom_type': '1 Bedroom', 'price': '$1,28...         Riverside
# 20       [{'bedroom_type': '1 Bedroom', 'price': ''}]          El Cajon
# 21  [{'bedroom_type': '1 Bedroom', 'price': ''}, {...        Sacramento
# 22  [{'bedroom_type': '1 Bedroom', 'price': '$1,34...          Temecula
# 23  [{'bedroom_type': '1 Bedroom', 'price': ''}, {...         San Diego
# 24  [{'bedroom_type': '1 Bedroom', 'price': '$960 ...            Fresno
#
#                      Property_Name_Rent State_Rent     Studio       Type  \
# 0                Homecoming At Eastvale         CA        NaN  Apartment
# 1                             The Pearl         CA  $1,879 –   Apartment
# 2             The Falls at Willow Creek         CA        NaN  Apartment
# 3                  Westcreek Apartments         CA        NaN  Apartment
# 4              Vista Gardens Apartments         CA        NaN  Apartment
# 5                           The Jackson         CA        NaN  Apartment
# 6                  Wedgewood Apartments         CA             Apartment
# 7                         eaves Fremont         CA        NaN  Apartment
# 8                              Harrison         CA  $1,870 –   Apartment
# 9         Torrey Villas Apartment Homes         CA        NaN  Apartment
# 10                     Avalon San Bruno         CA        NaN  Apartment
# 11                         The Verandas         CA        NaN  Apartment
# 12                         Kirker Creek         CA        NaN  Apartment
# 13          Pepperwood Knoll Apartments         CA        NaN  Apartment
# 14                     eaves San Marcos         CA        NaN  Apartment
# 15  Hensley at Corona Pointe Apartments         CA        NaN  Apartment
# 16               Villa Lucia Apartments         CA        NaN  Apartment
# 17           Berkeley Apartments - Gaia         CA        NaN  Apartment
# 18             Seacrest Apartment Homes         CA        NaN  Apartment
# 19                              Artessa         CA        NaN  Apartment
# 20               The Timbers Apartments         CA        NaN  Apartment
# 21                Greenridge Apartments         CA        NaN  Apartment
# 22                 Portofino Apartments         CA        NaN  Apartment
# 23                       Barclay Square         CA        NaN  Apartment
# 24                            Windscape         CA        NaN  Apartment
#
#    Zip_code
# 0     91752
# 1     90005
# 2     95630
# 3     91362
# 4     92543
# 5     92806
# 6     95831
# 7     94539
# 8     91203
# 9     92130
# 10    94066
# 11    91791
# 12    94565
# 13    95842
# 14    92069
# 15    92881
# 16    93722
# 17    94704
# 18    92672
# 19    92504
# 20    92020
# 21    95824
# 22    92591
# 23    92117
# 24    93711

# %%
# Export file as a CSV, without the Pandas index, but with the header
house_data.to_csv("Output/Q2-2018_Apartment_Apartment_Data2.csv", index=False, header=True)
