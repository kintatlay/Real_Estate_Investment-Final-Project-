# %%
# Dependencies
from bs4 import BeautifulSoup
import requests
import pandas as pd

# %%
#Testing
linked = 'https://www.century21.com/real-estate/california/LSCA/'

response = requests.get(linked)
soup = BeautifulSoup(response.text, 'html.parser')
result = soup.find_all('div', class_='infinite-item')
result
# Out:
# [<div class="infinite-item property-card clearfix property-card-C2180910323" data-brand-cd="C21" data-id="C2180910323" data-latitude="38.02535" data-link="/property/22216-parrotts-ferry-13-sonora-ca-95370-C2180910323" data-listing-id="" data-longitude="-120.40381" data-mls="20181467" data-source-id="56dafcea-766d-461e-97bc-6ee9e5eb9983" data-zip="95370">
#  <div class="property-card-clip"> <div class="property-card-image" style="background-image: url(https://www2.century21.com/c21/photo/maxxmax/c21.azureedge.net/308i0/0r6e05264hncmdte4j3a11qnf4i);">
#  <div class="property-image-flag newly-listed">Newly Listed</div>
#  <div class="property-image-count">
#  <div class="image-count-left">&lt;</div>
#  <div class="image-count-current">1</div>
#  <div class="image-count-total">12</div>
#  <div class="image-count-right">&gt;</div>
#  </div>
#  </div>
#  </div>
#  <div class="property-card-primary-info">
#  <div class="pdp-listing-type sale">FOR SALE</div>
#  <a class="listing-price" href="/property/22216-parrotts-ferry-13-sonora-ca-95370-C2180910323">
#
#
#                 $15,990,000
#
#
#
#        </a>
#  <div class="col-wrap-mid">
#  <div class="property-beds">
#  <strong>2</strong> beds
#           </div>
#  <div class="property-baths">
#  <strong>1</strong> bath
#           </div>
#  </div>
#  <div class="col-wrap-last">
#  <div class="property-sqft">
#  <strong>550</strong> sq. ft
#           </div>
#  </div>
#  <div class="property-address-info">
#  <div class="property-address" title="22216 Parrotts Ferry #13">
#                 22216 Parrotts Ferry #13
#              </div>
#  <div class="property-city">
#              Sonora CA 95370
#           </div>
#  </div>
#  <div class="property-card-attribution">
#                 Listed By CENTURY 21 Wildwood Properties, Inc.
#
#           </div>
#  </div>
#  <div class="property-actions">
#  <button class="action-contact" data-usagetrack='{"data": ["Hybrid Mapping", "Property Card", "Contact"]}' title="Contact" type="button"></button>
#  <button class="action-favorite" title="Set as Favorite" type="button"></button>
#  </div>
#  </div>,
#  <div class="infinite-item property-card clearfix property-card-C2180911172" data-brand-cd="C21" data-id="C2180911172" data-latitude="34.05225" data-link="/property/2222-avenue-of-the-stars-1201e-los-angeles-ca-90067-C2180911172" data-listing-id="" data-longitude="-118.40849" data-mls="SR18185481" data-source-id="1ce7de9f-1e19-450c-ada1-733e0b83043f" data-zip="90067">
#  <div class="property-card-clip"> <div class="property-card-image" style="background-image: url(https://www2.century21.com/c21/photo/maxxmax/c21.azureedge.net/1103i0/81w4s1yg233vmejryeetvt85y3i);">
#  <div class="property-image-flag newly-listed">Newly Listed</div>
#  <div class="property-image-count">
#  <div class="image-count-left">&lt;</div>
#  <div class="image-count-current">1</div>
#  <div class="image-count-total">35</div>
#  <div class="image-count-right">&gt;</div>
#  </div>
#  </div>
#  </div>
#  <div class="property-card-primary-info">
#  <div class="pdp-listing-type sale">FOR SALE</div>
#  <a class="listing-price" href="/property/2222-avenue-of-the-stars-1201e-los-angeles-ca-90067-C2180911172">
#
#
#                 $1,949,000
#
#
#
#        </a>
#  <div class="col-wrap-mid">
#  <div class="property-beds">
#  <strong>2</strong> beds
#           </div>
#  <div class="property-baths">
#  <strong>2</strong> baths
#           </div>
#  </div>
#  <div class="col-wrap-last">
#  <div class="property-sqft">
#  <strong>1,639</strong> sq. ft
#           </div>
#  </div>
#  <div class="property-address-info">
#  <div class="property-address" title="2222 Avenue of the Stars 1201E">
#                 2222 Avenue of the Stars 1201E
#              </div>
#  <div class="property-city">
#              Los Angeles CA 90067
#           </div>
#  </div>
#  <div class="property-card-attribution">
#                 Listed By CENTURY 21 Peak
#
#           </div>
#  </div>
#  <div class="property-actions">
#  <button class="action-contact" data-usagetrack='{"data": ["Hybrid Mapping", "Property Card", "Contact"]}' title="Contact" type="button"></button>
#  <button class="action-favorite" title="Set as Favorite" type="button"></button>
#  </div>
#  </div>,
#  <div class="infinite-item property-card clearfix property-card-C2180911239" data-brand-cd="C21" data-id="C2180911239" data-latitude="38.44093" data-link="/property/5167-hall-rd-santa-rosa-ca-95401-C2180911239" data-listing-id="" data-longitude="-122.80131" data-mls="18051792" data-source-id="c67b5759-1065-4365-a58f-d9c97a3d511b" data-zip="95401">
#  <div class="property-card-clip"> <div class="property-card-image" style="background-image: url(https://www2.century21.com/c21/photo/maxxmax/c21.azureedge.net/1203i0/4dhx2p4madc3476ngnp6ace7k7i);">
#  <div class="property-image-flag newly-listed">Newly Listed</div>
#  <div class="property-image-count">
#  <div class="image-count-left">&lt;</div>
#  <div class="image-count-current">1</div>
#  <div class="image-count-total">36</div>
#  <div class="image-count-right">&gt;</div>
#  </div>
#  </div>
#  </div>
#  <div class="property-card-primary-info">
#  <div class="pdp-listing-type sale">FOR SALE</div>
#  <a class="listing-price" href="/property/5167-hall-rd-santa-rosa-ca-95401-C2180911239">
#
#
#                 $1,500,000
#
#
#
#        </a>
#  <div class="col-wrap-mid">
#  <div class="property-beds">
#  <strong>4</strong> beds
#           </div>
#  <div class="property-baths">
#  <strong>3</strong> baths
#           </div>
#  </div>
#  <div class="col-wrap-last">
#  <div class="property-sqft">
#  <strong>3,671</strong> sq. ft
#           </div>
#  </div>
#  <div class="property-address-info">
#  <div class="property-address" title="5167 Hall Rd">
#                 5167 Hall Rd
#              </div>
#  <div class="property-city">
#              Santa Rosa CA 95401
#           </div>
#  </div>
#  <div class="property-card-attribution">
#                 Listed By CENTURY 21 MM
#
#           </div>
#  </div>
#  <div class="property-actions">
#  <button class="action-contact" data-usagetrack='{"data": ["Hybrid Mapping", "Property Card", "Contact"]}' title="Contact" type="button"></button>
#  <button class="action-favorite" title="Set as Favorite" type="button"></button>
#  </div>
#  </div>,
#  <div class="infinite-item property-card clearfix property-card-C2180910373" data-brand-cd="C21" data-id="C2180910373" data-latitude="38.247959" data-link="/property/1038-allen-street-petaluma-ca-94954-C2180910373" data-listing-id="" data-longitude="-122.594025" data-mls="21819956" data-source-id="94bab554-f566-4c94-86da-cab254545e23" data-zip="94954">
#  <div class="property-card-clip"> <div class="property-card-image" style="background-image: url(https://www2.century21.com/c21/photo/maxxmax/c21.azureedge.net/308i0/qxhkqbgkp7xwmxyjna4hkwwnd5i);">
#  <div class="property-image-flag newly-listed">Newly Listed</div>
#  <div class="property-image-count">
#  <div class="image-count-left">&lt;</div>
#  <div class="image-count-current">1</div>
#  <div class="image-count-total">41</div>
#  <div class="image-count-right">&gt;</div>
#  </div>
#  </div>
#  </div>
#  <div class="property-card-primary-info">
#  <div class="pdp-listing-type sale">FOR SALE</div>
#  <a class="listing-price" href="/property/1038-allen-street-petaluma-ca-94954-C2180910373">
#
#
#                 $979,000
#
#
#
#        </a>
#  <div class="col-wrap-mid">
#  <div class="property-beds">
#  <strong>5</strong> beds
#           </div>
#  <div class="property-baths">
#  <strong>3</strong> baths
#           </div>
#  </div>
#  <div class="col-wrap-last">
#  <div class="property-half-baths">
#  <strong>1</strong> half bath
#           </div>
#  <div class="property-sqft">
#  <strong>2,858</strong> sq. ft
#           </div>
#  </div>
#  <div class="property-address-info">
#  <div class="property-address" title="1038 Allen Street">
#                 1038 Allen Street
#              </div>
#  <div class="property-city">
#              Petaluma CA 94954
#           </div>
#  </div>
#  <div class="property-card-attribution">
#                 Listed By CENTURY 21 Bundesen
#
#           </div>
#  </div>
#  <div class="property-actions">
#  <button class="action-contact" data-usagetrack='{"data": ["Hybrid Mapping", "Property Card", "Contact"]}' title="Contact" type="button"></button>
#  <button class="action-favorite" title="Set as Favorite" type="button"></button>
#  </div>
#  </div>,
#  <div class="infinite-item property-card clearfix property-card-C2180911032" data-brand-cd="C21" data-id="C2180911032" data-latitude="37.65842" data-link="/property/25123-belmont-ave-hayward-ca-94542-C2180911032" data-listing-id="" data-longitude="-122.0718" data-mls="40832572" data-source-id="34292814-fcc4-459f-b8c0-252fc84058c7" data-zip="94542">
#  <div class="property-card-clip"> <div class="property-card-image" style="background-image: url(https://www2.century21.com/c21/photo/maxxmax/c21.azureedge.net/1203i0/e84vskrsb8g144p2fm86hhrc96i);">
#  <div class="property-image-flag newly-listed">Newly Listed</div>
#  <div class="property-image-count">
#  <div class="image-count-left">&lt;</div>
#  <div class="image-count-current">1</div>
#  <div class="image-count-total">35</div>
#  <div class="image-count-right">&gt;</div>
#  </div>
#  </div>
#  </div>
#  <div class="property-card-primary-info">
#  <div class="pdp-listing-type sale">FOR SALE</div>
#  <a class="listing-price" href="/property/25123-belmont-ave-hayward-ca-94542-C2180911032">
#
#
#                 $777,000
#
#
#
#        </a>
#  <div class="col-wrap-mid">
#  <div class="property-beds">
#  <strong>4</strong> beds
#           </div>
#  <div class="property-baths">
#  <strong>2</strong> baths
#           </div>
#  </div>
#  <div class="col-wrap-last">
#  <div class="property-sqft">
#  <strong>1,287</strong> sq. ft
#           </div>
#  </div>
#  <div class="property-address-info">
#  <div class="property-address" title="25123 Belmont Ave">
#                 25123 Belmont Ave
#              </div>
#  <div class="property-city">
#              Hayward CA 94542
#           </div>
#  </div>
#  <div class="property-card-attribution">
#                 Listed By CENTURY 21 MM
#
#           </div>
#  </div>
#  <div class="property-actions">
#  <button class="action-contact" data-usagetrack='{"data": ["Hybrid Mapping", "Property Card", "Contact"]}' title="Contact" type="button"></button>
#  <button class="action-favorite" title="Set as Favorite" type="button"></button>
#  </div>
#  </div>,
#  <div class="infinite-item property-card clearfix property-card-C2180911267" data-brand-cd="C21" data-id="C2180911267" data-latitude="38.28624" data-link="/property/1873-seville-dr-napa-ca-94559-C2180911267" data-listing-id="" data-longitude="-122.26038" data-mls="21819703" data-source-id="89d4bf57-b14a-4b19-95fd-e8bfbe00441d" data-zip="94559">
#  <div class="property-card-clip"> <div class="property-card-image" style="background-image: url(https://www2.century21.com/c21/photo/maxxmax/c21.azureedge.net/1203i0/63bqec99rc8242pyzxm2yy7051i);">
#  <div class="property-image-flag newly-listed">Newly Listed</div>
#  <div class="property-image-count">
#  <div class="image-count-left">&lt;</div>
#  <div class="image-count-current">1</div>
#  <div class="image-count-total">36</div>
#  <div class="image-count-right">&gt;</div>
#  </div>
#  </div>
#  </div>
#  <div class="property-card-primary-info">
#  <div class="pdp-listing-type sale">FOR SALE</div>
#  <a class="listing-price" href="/property/1873-seville-dr-napa-ca-94559-C2180911267">
#
#
#                 $750,000
#
#
#
#        </a>
#  <div class="col-wrap-mid">
#  <div class="property-beds">
#  <strong>4</strong> beds
#           </div>
#  <div class="property-baths">
#  <strong>2</strong> baths
#           </div>
#  </div>
#  <div class="col-wrap-last">
#  <div class="property-sqft">
#  <strong>2,115</strong> sq. ft
#           </div>
#  </div>
#  <div class="property-address-info">
#  <div class="property-address" title="1873 Seville Dr">
#                 1873 Seville Dr
#              </div>
#  <div class="property-city">
#              Napa CA 94559
#           </div>
#  </div>
#  <div class="property-card-attribution">
#                 Listed By CENTURY 21 MM
#
#           </div>
#  </div>
#  <div class="property-actions">
#  <button class="action-contact" data-usagetrack='{"data": ["Hybrid Mapping", "Property Card", "Contact"]}' title="Contact" type="button"></button>
#  <button class="action-favorite" title="Set as Favorite" type="button"></button>
#  </div>
#  </div>,
#  <div class="infinite-item property-card clearfix property-card-C2180911299" data-brand-cd="C21" data-id="C2180911299" data-latitude="33.91568" data-link="/property/14828-ramhurst-drive-la-mirada-ca-90638-C2180911299" data-listing-id="" data-longitude="-118.0154" data-mls="pw18180746" data-source-id="3b56215d-75c9-4b39-a4e9-fab0c2a93137" data-zip="90638">
#  <div class="property-card-clip"> <div class="property-card-image" style="background-image: url(https://www2.century21.com/c21/photo/maxxmax/c21.azureedge.net/1103i0/kdtbbv8gvvkt4me5bpngvvhqx1i);">
#  <div class="property-image-flag open-house">Open House</div>
#  <div class="property-image-count">
#  <div class="image-count-left">&lt;</div>
#  <div class="image-count-current">1</div>
#  <div class="image-count-total">24</div>
#  <div class="image-count-right">&gt;</div>
#  </div>
#  </div>
#  </div>
#  <div class="property-card-primary-info">
#  <div class="pdp-listing-type sale">FOR SALE</div>
#  <a class="listing-price" href="/property/14828-ramhurst-drive-la-mirada-ca-90638-C2180911299">
#
#
#                 $615,000
#
#
#
#        </a>
#  <div class="col-wrap-mid">
#  <div class="property-beds">
#  <strong>3</strong> beds
#           </div>
#  <div class="property-baths">
#  <strong>2</strong> baths
#           </div>
#  </div>
#  <div class="col-wrap-last">
#  <div class="property-sqft">
#  <strong>1,452</strong> sq. ft
#           </div>
#  </div>
#  <div class="property-address-info">
#  <div class="property-address" title="14828 Ramhurst Drive">
#                 14828 Ramhurst Drive
#              </div>
#  <div class="property-city">
#              La Mirada CA 90638
#           </div>
#  </div>
#  <div class="property-card-attribution">
#                 Listed By CENTURY 21 Westworld Realty
#
#           </div>
#  </div>
#  <div class="property-actions">
#  <button class="action-contact" data-usagetrack='{"data": ["Hybrid Mapping", "Property Card", "Contact"]}' title="Contact" type="button"></button>
#  <button class="action-favorite" title="Set as Favorite" type="button"></button>
#  </div>
#  </div>,
#  <div class="infinite-item property-card clearfix property-card-C2180911269" data-brand-cd="C21" data-id="C2180911269" data-latitude="35.60401" data-link="/property/820-saint-andrews-circle-paso-robles-ca-93446-C2180911269" data-listing-id="" data-longitude="-120.66757" data-mls="NS18184911" data-source-id="8392d584-b17e-4083-a3d9-b15f4e26ac5c" data-zip="93446">
#  <div class="property-card-clip"> <div class="property-card-image" style="background-image: url(https://www2.century21.com/c21/photo/maxxmax/c21.azureedge.net/1103i0/fe7x9kzr86eymq6z7prrkzdaw1i);">
#  <div class="property-image-flag newly-listed">Newly Listed</div>
#  <div class="property-image-count">
#  <div class="image-count-left">&lt;</div>
#  <div class="image-count-current">1</div>
#  <div class="image-count-total">1</div>
#  <div class="image-count-right">&gt;</div>
#  </div>
#  </div>
#  </div>
#  <div class="property-card-primary-info">
#  <div class="pdp-listing-type sale">FOR SALE</div>
#  <a class="listing-price" href="/property/820-saint-andrews-circle-paso-robles-ca-93446-C2180911269">
#
#
#                 $559,950
#
#
#
#        </a>
#  <div class="col-wrap-mid">
#  <div class="property-beds">
#  <strong>3</strong> beds
#           </div>
#  <div class="property-baths">
#  <strong>2</strong> baths
#           </div>
#  </div>
#  <div class="col-wrap-last">
#  <div class="property-sqft">
#  <strong>1,821</strong> sq. ft
#           </div>
#  </div>
#  <div class="property-address-info">
#  <div class="property-address" title="820 Saint Andrews Circle">
#                 820 Saint Andrews Circle
#              </div>
#  <div class="property-city">
#              Paso Robles CA 93446
#           </div>
#  </div>
#  <div class="property-card-attribution">
#                 Listed By CENTURY 21 Hometown Realty
#
#           </div>
#  </div>
#  <div class="property-actions">
#  <button class="action-contact" data-usagetrack='{"data": ["Hybrid Mapping", "Property Card", "Contact"]}' title="Contact" type="button"></button>
#  <button class="action-favorite" title="Set as Favorite" type="button"></button>
#  </div>
#  </div>,
#  <div class="infinite-item property-card clearfix property-card-C2180911286" data-brand-cd="C21" data-id="C2180911286" data-latitude="38.80384" data-link="/property/3017-strand-rocklin-ca-95765-C2180911286" data-listing-id="" data-longitude="-121.26919" data-mls="18051794" data-source-id="b9ba3e31-4f6c-4e5c-a5f9-2b0a918151ef" data-zip="95765">
#  <div class="property-card-clip"> <div class="property-card-image" style="background-image: url(https://www2.century21.com/c21/photo/maxxmax/c21.azureedge.net/1203i0/f1f5sv7d758m4ee7bqcen8q4a4i);">
#  <div class="property-image-flag newly-listed">Newly Listed</div>
#  <div class="property-image-count">
#  <div class="image-count-left">&lt;</div>
#  <div class="image-count-current">1</div>
#  <div class="image-count-total">32</div>
#  <div class="image-count-right">&gt;</div>
#  </div>
#  </div>
#  </div>
#  <div class="property-card-primary-info">
#  <div class="pdp-listing-type sale">FOR SALE</div>
#  <a class="listing-price" href="/property/3017-strand-rocklin-ca-95765-C2180911286">
#
#
#                 $550,000
#
#
#
#        </a>
#  <div class="col-wrap-mid">
#  <div class="property-beds">
#  <strong>4</strong> beds
#           </div>
#  <div class="property-baths">
#  <strong>3</strong> baths
#           </div>
#  </div>
#  <div class="col-wrap-last">
#  <div class="property-sqft">
#  <strong>2,650</strong> sq. ft
#           </div>
#  </div>
#  <div class="property-address-info">
#  <div class="property-address" title="3017 Strand">
#                 3017 Strand
#              </div>
#  <div class="property-city">
#              Rocklin CA 95765
#           </div>
#  </div>
#  <div class="property-card-attribution">
#                 Listed By CENTURY 21 MM
#
#           </div>
#  </div>
#  <div class="property-actions">
#  <button class="action-contact" data-usagetrack='{"data": ["Hybrid Mapping", "Property Card", "Contact"]}' title="Contact" type="button"></button>
#  <button class="action-favorite" title="Set as Favorite" type="button"></button>
#  </div>
#  </div>,
#  <div class="infinite-item property-card clearfix property-card-C2180910401" data-brand-cd="C21" data-id="C2180910401" data-latitude="38.243362" data-link="/property/7-liberty-lane-petaluma-ca-94952-C2180910401" data-listing-id="" data-longitude="-122.648918" data-mls="21819792" data-source-id="4dfd3969-f182-4eff-b459-952c588c652d" data-zip="94952">
#  <div class="property-card-clip"> <div class="property-card-image" style="background-image: url(https://www2.century21.com/c21/photo/maxxmax/c21.azureedge.net/308i0/j3gz5b8qtpsd4c658825e32732i);">
#  <div class="property-image-flag newly-listed">Newly Listed</div>
#  <div class="property-image-count">
#  <div class="image-count-left">&lt;</div>
#  <div class="image-count-current">1</div>
#  <div class="image-count-total">26</div>
#  <div class="image-count-right">&gt;</div>
#  </div>
#  </div>
#  </div>
#  <div class="property-card-primary-info">
#  <div class="pdp-listing-type sale">FOR SALE</div>
#  <a class="listing-price" href="/property/7-liberty-lane-petaluma-ca-94952-C2180910401">
#
#
#                 $520,000
#
#
#
#        </a>
#  <div class="col-wrap-mid">
#  <div class="property-beds">
#  <strong>2</strong> beds
#           </div>
#  <div class="property-baths">
#  <strong>2</strong> baths
#           </div>
#  </div>
#  <div class="col-wrap-last">
#  <div class="property-sqft">
#  <strong>1,092</strong> sq. ft
#           </div>
#  </div>
#  <div class="property-address-info">
#  <div class="property-address" title="7 Liberty Lane">
#                 7 Liberty Lane
#              </div>
#  <div class="property-city">
#              Petaluma CA 94952
#           </div>
#  </div>
#  <div class="property-card-attribution">
#                 Listed By CENTURY 21 Bundesen
#
#           </div>
#  </div>
#  <div class="property-actions">
#  <button class="action-contact" data-usagetrack='{"data": ["Hybrid Mapping", "Property Card", "Contact"]}' title="Contact" type="button"></button>
#  <button class="action-favorite" title="Set as Favorite" type="button"></button>
#  </div>
#  </div>,
#  <div class="infinite-item property-card clearfix property-card-C2180911225" data-brand-cd="C21" data-id="C2180911225" data-latitude="36.98254" data-link="/property/16181-mark-rd-madera-ca-93636-C2180911225" data-listing-id="" data-longitude="-119.88914" data-mls="507584" data-source-id="be2e0d0a-cbad-4e2f-84d4-74d74e258b59" data-zip="93636">
#  <div class="property-card-clip"> <div class="property-card-image" style="background-image: url(https://dev.virtualearth.net/REST/v1/Imagery/Map/Aerial/36.98254,-119.88914/18?key=Aifo-Q0bU-2xqFafu5AzBNi5fz59f5ufmjxeulcOJc1DddNIqLLW5Sozv3EQ8dhn&amp;mapSize=800,600);">
#  <div class="property-image-flag newly-listed">Newly Listed</div>
#  <div class="property-image-count">
#  <div class="image-count-left">&lt;</div>
#  <div class="image-count-current">1</div>
#  <div class="image-count-total">1</div>
#  <div class="image-count-right">&gt;</div>
#  </div>
#  </div>
#  </div>
#  <div class="property-card-primary-info">
#  <div class="pdp-listing-type sale">FOR SALE</div>
#  <a class="listing-price" href="/property/16181-mark-rd-madera-ca-93636-C2180911225">
#
#
#                 $375,000
#
#
#
#        </a>
#  <div class="col-wrap-mid">
#  <div class="property-beds">
#  <strong>4</strong> beds
#           </div>
#  <div class="property-baths">
#  <strong>2</strong> baths
#           </div>
#  </div>
#  <div class="col-wrap-last">
#  <div class="property-sqft">
#  <strong>1,941</strong> sq. ft
#           </div>
#  </div>
#  <div class="property-address-info">
#  <div class="property-address" title="16181 Mark Rd">
#                 16181 Mark Rd
#              </div>
#  <div class="property-city">
#              Madera CA 93636
#           </div>
#  </div>
#  <div class="property-card-attribution">
#                 Listed By CENTURY 21 MM
#
#           </div>
#  </div>
#  <div class="property-actions">
#  <button class="action-contact" data-usagetrack='{"data": ["Hybrid Mapping", "Property Card", "Contact"]}' title="Contact" type="button"></button>
#  <button class="action-favorite" title="Set as Favorite" type="button"></button>
#  </div>
#  </div>,
#  <div class="infinite-item property-card clearfix property-card-C2180911270" data-brand-cd="C21" data-id="C2180911270" data-latitude="37.77773" data-link="/property/831-river-bluff-ct-oakdale-ca-95361-C2180911270" data-listing-id="" data-longitude="-120.84571" data-mls="18051424" data-source-id="ecb33656-cafc-4164-a7c6-74ff14819863" data-zip="95361">
#  <div class="property-card-clip"> <div class="property-card-image" style="background-image: url(https://www2.century21.com/c21/photo/maxxmax/c21.azureedge.net/1203i0/vkn5vbjpepgy4e6t44vs09kh20i);">
#  <div class="property-image-flag newly-listed">Newly Listed</div>
#  <div class="property-image-count">
#  <div class="image-count-left">&lt;</div>
#  <div class="image-count-current">1</div>
#  <div class="image-count-total">34</div>
#  <div class="image-count-right">&gt;</div>
#  </div>
#  </div>
#  </div>
#  <div class="property-card-primary-info">
#  <div class="pdp-listing-type sale">FOR SALE</div>
#  <a class="listing-price" href="/property/831-river-bluff-ct-oakdale-ca-95361-C2180911270">
#
#
#                 $375,000
#
#
#
#        </a>
#  <div class="col-wrap-mid">
#  <div class="property-beds">
#  <strong>3</strong> beds
#           </div>
#  <div class="property-baths">
#  <strong>2</strong> baths
#           </div>
#  </div>
#  <div class="col-wrap-last">
#  <div class="property-sqft">
#  <strong>1,738</strong> sq. ft
#           </div>
#  </div>
#  <div class="property-address-info">
#  <div class="property-address" title="831 River Bluff Ct">
#                 831 River Bluff Ct
#              </div>
#  <div class="property-city">
#              Oakdale CA 95361
#           </div>
#  </div>
#  <div class="property-card-attribution">
#                 Listed By CENTURY 21 MM
#
#           </div>
#  </div>
#  <div class="property-actions">
#  <button class="action-contact" data-usagetrack='{"data": ["Hybrid Mapping", "Property Card", "Contact"]}' title="Contact" type="button"></button>
#  <button class="action-favorite" title="Set as Favorite" type="button"></button>
#  </div>
#  </div>,
#  <div class="infinite-item property-card clearfix property-card-C2180911353" data-brand-cd="C21" data-id="C2180911353" data-latitude="38.25347" data-link="/property/737-dean-way-arnold-ca-95223-C2180911353" data-listing-id="" data-longitude="-120.33495" data-mls="1801851" data-source-id="56624ddd-051b-4af9-b2aa-bf4503b4f081" data-zip="95223">
#  <div class="property-card-clip"> <div class="property-card-image" style="background-image: url(https://www2.century21.com/c21/photo/maxxmax/c21.azureedge.net/308i0/r3edpt21pwvf4by5t02fkzgye4i);">
#  <div class="property-image-flag newly-listed">Newly Listed</div>
#  <div class="property-image-count">
#  <div class="image-count-left">&lt;</div>
#  <div class="image-count-current">1</div>
#  <div class="image-count-total">21</div>
#  <div class="image-count-right">&gt;</div>
#  </div>
#  </div>
#  </div>
#  <div class="property-card-primary-info">
#  <div class="pdp-listing-type sale">FOR SALE</div>
#  <a class="listing-price" href="/property/737-dean-way-arnold-ca-95223-C2180911353">
#
#
#                 $369,000
#
#
#
#        </a>
#  <div class="col-wrap-mid">
#  <div class="property-beds">
#  <strong>3</strong> beds
#           </div>
#  <div class="property-baths">
#  <strong>2</strong> baths
#           </div>
#  </div>
#  <div class="col-wrap-last">
#  <div class="property-sqft">
#  <strong>1,704</strong> sq. ft
#           </div>
#  </div>
#  <div class="property-address-info">
#  <div class="property-address" title="737 Dean Way">
#                 737 Dean Way
#              </div>
#  <div class="property-city">
#              Arnold CA 95223
#           </div>
#  </div>
#  <div class="property-card-attribution">
#                 Listed By CENTURY 21 Sierra Properties
#
#           </div>
#  </div>
#  <div class="property-actions">
#  <button class="action-contact" data-usagetrack='{"data": ["Hybrid Mapping", "Property Card", "Contact"]}' title="Contact" type="button"></button>
#  <button class="action-favorite" title="Set as Favorite" type="button"></button>
#  </div>
#  </div>,
#  <div class="infinite-item property-card clearfix property-card-C2180911024" data-brand-cd="C21" data-id="C2180911024" data-latitude="35.26114" data-link="/property/1750-prefumo-canyon-rd-55-san-luis-obispo-ca-93405-C2180911024" data-listing-id="" data-longitude="-120.70168" data-mls="SP18184075" data-source-id="9801552e-737b-4b26-8c8d-6ec8a67b4d5e" data-zip="93405">
#  <div class="property-card-clip"> <div class="property-card-image" style="background-image: url(https://www2.century21.com/c21/photo/maxxmax/c21.azureedge.net/1103i0/1790yyt6ds20mat2s69c736664i);">
#  <div class="property-image-flag newly-listed">Newly Listed</div>
#  <div class="property-image-count">
#  <div class="image-count-left">&lt;</div>
#  <div class="image-count-current">1</div>
#  <div class="image-count-total">15</div>
#  <div class="image-count-right">&gt;</div>
#  </div>
#  </div>
#  </div>
#  <div class="property-card-primary-info">
#  <div class="pdp-listing-type sale">FOR SALE</div>
#  <a class="listing-price" href="/property/1750-prefumo-canyon-rd-55-san-luis-obispo-ca-93405-C2180911024">
#
#
#                 $369,000
#
#
#
#        </a>
#  <div class="col-wrap-mid">
#  <div class="property-beds">
#  <strong>2</strong> beds
#           </div>
#  <div class="property-baths">
#  <strong>1</strong> bath
#           </div>
#  </div>
#  <div class="col-wrap-last">
#  <div class="property-half-baths">
#  <strong>1</strong> half bath
#           </div>
#  <div class="property-sqft">
#  <strong>1,001</strong> sq. ft
#           </div>
#  </div>
#  <div class="property-address-info">
#  <div class="property-address" title="1750 Prefumo Canyon Rd. #55">
#                 1750 Prefumo Canyon Rd. #55
#              </div>
#  <div class="property-city">
#              San Luis Obispo CA 93405
#           </div>
#  </div>
#  <div class="property-card-attribution">
#                 Listed By CENTURY 21 Hometown Realty
#
#           </div>
#  </div>
#  <div class="property-actions">
#  <button class="action-contact" data-usagetrack='{"data": ["Hybrid Mapping", "Property Card", "Contact"]}' title="Contact" type="button"></button>
#  <button class="action-favorite" title="Set as Favorite" type="button"></button>
#  </div>
#  </div>,
#  <div class="infinite-item property-card clearfix property-card-C2180911455" data-brand-cd="C21" data-id="C2180911455" data-latitude="33.71221" data-link="/property/28161-cannon-drive-sun-city-ca-92585-C2180911455" data-listing-id="" data-longitude="-117.17583" data-mls="IG18185338" data-source-id="600e1b49-d6a8-472f-a531-ea594bebc513" data-zip="92585">
#  <div class="property-card-clip"> <div class="property-card-image" style="background-image: url(https://dev.virtualearth.net/REST/v1/Imagery/Map/Aerial/33.71221,-117.17583/18?key=Aifo-Q0bU-2xqFafu5AzBNi5fz59f5ufmjxeulcOJc1DddNIqLLW5Sozv3EQ8dhn&amp;mapSize=800,600);">
#  <div class="property-image-flag newly-listed">Newly Listed</div>
#  <div class="property-image-count">
#  <div class="image-count-left">&lt;</div>
#  <div class="image-count-current">1</div>
#  <div class="image-count-total">1</div>
#  <div class="image-count-right">&gt;</div>
#  </div>
#  </div>
#  </div>
#  <div class="property-card-primary-info">
#  <div class="pdp-listing-type sale">FOR SALE</div>
#  <a class="listing-price" href="/property/28161-cannon-drive-sun-city-ca-92585-C2180911455">
#
#
#                 $358,800
#
#
#
#        </a>
#  <div class="col-wrap-mid">
#  <div class="property-beds">
#  <strong>4</strong> beds
#           </div>
#  <div class="property-baths">
#  <strong>2</strong> baths
#           </div>
#  </div>
#  <div class="col-wrap-last">
#  <div class="property-sqft">
#  <strong>1,892</strong> sq. ft
#           </div>
#  </div>
#  <div class="property-address-info">
#  <div class="property-address" title="28161 Cannon Drive">
#                 28161 Cannon Drive
#              </div>
#  <div class="property-city">
#              Sun City CA 92585
#           </div>
#  </div>
#  <div class="property-card-attribution">
#                 Listed By CENTURY 21 Beachside, Realtors
#
#           </div>
#  </div>
#  <div class="property-actions">
#  <button class="action-contact" data-usagetrack='{"data": ["Hybrid Mapping", "Property Card", "Contact"]}' title="Contact" type="button"></button>
#  <button class="action-favorite" title="Set as Favorite" type="button"></button>
#  </div>
#  </div>,
#  <div class="infinite-item property-card clearfix property-card-C2180910485" data-brand-cd="C21" data-id="C2180910485" data-latitude="33.6609" data-link="/property/20702-el-toro-rd-lake-forest-ca-92630-C2180910485" data-listing-id="" data-longitude="-117.64544" data-mls="PW18184136" data-source-id="670667d4-7769-4baa-8c0a-2bf3a6333109" data-zip="92630">
#  <div class="property-card-clip"> <div class="property-card-image" style="background-image: url(https://www2.century21.com/c21/photo/maxxmax/c21.azureedge.net/1136i0/282bhjy2vgx44qpfk8dzchf1b6i);">
#  <div class="property-image-flag open-house">Open Houses</div>
#  <div class="property-image-count">
#  <div class="image-count-left">&lt;</div>
#  <div class="image-count-current">1</div>
#  <div class="image-count-total">17</div>
#  <div class="image-count-right">&gt;</div>
#  </div>
#  </div>
#  </div>
#  <div class="property-card-primary-info">
#  <div class="pdp-listing-type sale">FOR SALE</div>
#  <a class="listing-price" href="/property/20702-el-toro-rd-lake-forest-ca-92630-C2180910485">
#
#
#                 $354,999
#
#
#
#        </a>
#  <div class="col-wrap-mid">
#  <div class="property-beds">
#  <strong>2</strong> beds
#           </div>
#  <div class="property-baths">
#  <strong>2</strong> baths
#           </div>
#  </div>
#  <div class="col-wrap-last">
#  </div>
#  <div class="property-address-info">
#  <div class="property-address" title="20702 El Toro Rd">
#                 20702 El Toro Rd
#              </div>
#  <div class="property-city">
#              Lake Forest CA 92630
#           </div>
#  </div>
#  <div class="property-card-attribution">
#                 Listed By CENTURY 21 Award
#
#           </div>
#  </div>
#  <div class="property-actions">
#  <button class="action-contact" data-usagetrack='{"data": ["Hybrid Mapping", "Property Card", "Contact"]}' title="Contact" type="button"></button>
#  <button class="action-favorite" title="Set as Favorite" type="button"></button>
#  </div>
#  </div>,
#  <div class="infinite-item property-card clearfix property-card-C2180910342" data-brand-cd="C21" data-id="C2180910342" data-latitude="34.4570273967373" data-link="/property/11341-seventh-avenue-hesperia-ca-92345-C2180910342" data-listing-id="" data-longitude="-117.312185466025" data-mls="502981" data-source-id="57bddaac-b843-421f-805d-948934e0bf50" data-zip="92345">
#  <div class="property-card-clip"> <div class="property-card-image" style="background-image: url(https://www2.century21.com/c21/photo/maxxmax/c21.azureedge.net/308i0/9jena7q24xgg4j2m8smcwzwze1i);">
#  <div class="property-image-flag newly-listed">Newly Listed</div>
#  <div class="property-image-count">
#  <div class="image-count-left">&lt;</div>
#  <div class="image-count-current">1</div>
#  <div class="image-count-total">20</div>
#  <div class="image-count-right">&gt;</div>
#  </div>
#  </div>
#  </div>
#  <div class="property-card-primary-info">
#  <div class="pdp-listing-type sale">FOR SALE</div>
#  <a class="listing-price" href="/property/11341-seventh-avenue-hesperia-ca-92345-C2180910342">
#
#
#                 $348,000
#
#
#
#        </a>
#  <div class="col-wrap-mid">
#  <div class="property-beds">
#  <strong>4</strong> beds
#           </div>
#  <div class="property-baths">
#  <strong>2</strong> baths
#           </div>
#  </div>
#  <div class="col-wrap-last">
#  <div class="property-sqft">
#  <strong>2,100</strong> sq. ft
#           </div>
#  </div>
#  <div class="property-address-info">
#  <div class="property-address" title="11341 Seventh Avenue">
#                 11341 Seventh Avenue
#              </div>
#  <div class="property-city">
#              Hesperia CA 92345
#           </div>
#  </div>
#  <div class="property-card-attribution">
#                 Listed By CENTURY 21 Rose Realty
#
#           </div>
#  </div>
#  <div class="property-actions">
#  <button class="action-contact" data-usagetrack='{"data": ["Hybrid Mapping", "Property Card", "Contact"]}' title="Contact" type="button"></button>
#  <button class="action-favorite" title="Set as Favorite" type="button"></button>
#  </div>
#  </div>,
#  <div class="infinite-item property-card clearfix property-card-C2180910341" data-brand-cd="C21" data-id="C2180910341" data-latitude="34.54718" data-link="/property/apple-valley-ca-92307-C2180910341" data-listing-id="" data-longitude="-117.1302" data-mls="502982" data-source-id="35c07b94-72e5-48f3-bf6f-b1c62db92836" data-zip="92307">
#  <div class="property-card-clip"> <div class="property-card-image" style="background-image: url(https://www2.century21.com/c21/photo/maxxmax/c21.azureedge.net/308i0/74w6nv8cv14w49aytrx9k66hy0i);">
#  <div class="property-image-flag newly-listed">Newly Listed</div>
#  <div class="property-image-count">
#  <div class="image-count-left">&lt;</div>
#  <div class="image-count-current">1</div>
#  <div class="image-count-total">14</div>
#  <div class="image-count-right">&gt;</div>
#  </div>
#  </div>
#  </div>
#  <div class="property-card-primary-info">
#  <div class="pdp-listing-type sale">FOR SALE</div>
#  <a class="listing-price" href="/property/apple-valley-ca-92307-C2180910341">
#
#
#                 $238,500
#
#
#
#        </a>
#  <div class="col-wrap-mid">
#  <div class="property-beds">
#  <strong>3</strong> beds
#           </div>
#  <div class="property-baths">
#  <strong>3</strong> baths
#           </div>
#  </div>
#  <div class="col-wrap-last">
#  <div class="property-half-baths">
#  <strong>1</strong> half bath
#           </div>
#  <div class="property-sqft">
#  <strong>1,904</strong> sq. ft
#           </div>
#  </div>
#  <div class="property-address-info">
#  <div class="property-city">
#              Apple Valley CA 92307
#           </div>
#  </div>
#  <div class="property-card-attribution">
#                 Listed By CENTURY 21 Fairway Realty
#
#           </div>
#  </div>
#  <div class="property-actions">
#  <button class="action-contact" data-usagetrack='{"data": ["Hybrid Mapping", "Property Card", "Contact"]}' title="Contact" type="button"></button>
#  <button class="action-favorite" title="Set as Favorite" type="button"></button>
#  </div>
#  </div>,
#  <div class="infinite-item property-card clearfix property-card-C2180910474" data-brand-cd="C21" data-id="C2180910474" data-latitude="38.12397" data-link="/property/201-cherry-st-lodi-ca-95240-C2180910474" data-listing-id="" data-longitude="-121.26946" data-mls="18052463" data-source-id="f335fe1e-047c-4fe2-909d-05ed6e66db39" data-zip="95240">
#  <div class="property-card-clip"> <div class="property-card-image" style="background-image: url(https://www2.century21.com/c21/photo/maxxmax/c21.azureedge.net/1203i0/yfpa0tgka3rn4fy0zw3125ptt2i);">
#  <div class="property-image-flag newly-listed">Newly Listed</div>
#  <div class="property-image-count">
#  <div class="image-count-left">&lt;</div>
#  <div class="image-count-current">1</div>
#  <div class="image-count-total">20</div>
#  <div class="image-count-right">&gt;</div>
#  </div>
#  </div>
#  </div>
#  <div class="property-card-primary-info">
#  <div class="pdp-listing-type sale">FOR SALE</div>
#  <a class="listing-price" href="/property/201-cherry-st-lodi-ca-95240-C2180910474">
#
#
#                 $225,000
#
#
#
#        </a>
#  <div class="col-wrap-mid">
#  <div class="property-beds">
#  <strong>2</strong> beds
#           </div>
#  <div class="property-baths">
#  <strong>1</strong> bath
#           </div>
#  </div>
#  <div class="col-wrap-last">
#  <div class="property-sqft">
#  <strong>812</strong> sq. ft
#           </div>
#  </div>
#  <div class="property-address-info">
#  <div class="property-address" title="201 Cherry St">
#                 201 Cherry St
#              </div>
#  <div class="property-city">
#              Lodi CA 95240
#           </div>
#  </div>
#  <div class="property-card-attribution">
#                 Listed By CENTURY 21 MM
#
#           </div>
#  </div>
#  <div class="property-actions">
#  <button class="action-contact" data-usagetrack='{"data": ["Hybrid Mapping", "Property Card", "Contact"]}' title="Contact" type="button"></button>
#  <button class="action-favorite" title="Set as Favorite" type="button"></button>
#  </div>
#  </div>,
#  <div class="infinite-item property-card clearfix property-card-C2180910330" data-brand-cd="C21" data-id="C2180910330" data-latitude="34.51539" data-link="/property/14426-windmill-circle-victorville-ca-92394-C2180910330" data-listing-id="" data-longitude="-117.34837" data-mls="502954" data-source-id="fc4f53a0-60be-4230-8eb3-a3386406eca4" data-zip="92394">
#  <div class="property-card-clip"> <div class="property-card-image" style="background-image: url(https://www2.century21.com/c21/photo/maxxmax/c21.azureedge.net/308i0/2k8edbtxnq5q4jtz78hbf9n013i);">
#  <div class="property-image-flag newly-listed">Newly Listed</div>
#  <div class="property-image-count">
#  <div class="image-count-left">&lt;</div>
#  <div class="image-count-current">1</div>
#  <div class="image-count-total">19</div>
#  <div class="image-count-right">&gt;</div>
#  </div>
#  </div>
#  </div>
#  <div class="property-card-primary-info">
#  <div class="pdp-listing-type sale">FOR SALE</div>
#  <a class="listing-price" href="/property/14426-windmill-circle-victorville-ca-92394-C2180910330">
#
#
#                 $212,500
#
#
#
#        </a>
#  <div class="col-wrap-mid">
#  <div class="property-beds">
#  <strong>3</strong> beds
#           </div>
#  <div class="property-baths">
#  <strong>2</strong> baths
#           </div>
#  </div>
#  <div class="col-wrap-last">
#  <div class="property-sqft">
#  <strong>994</strong> sq. ft
#           </div>
#  </div>
#  <div class="property-address-info">
#  <div class="property-address" title="14426 Windmill Circle">
#                 14426 Windmill Circle
#              </div>
#  <div class="property-city">
#              Victorville CA 92394
#           </div>
#  </div>
#  <div class="property-card-attribution">
#                 Listed By CENTURY 21 Rose Realty
#
#           </div>
#  </div>
#  <div class="property-actions">
#  <button class="action-contact" data-usagetrack='{"data": ["Hybrid Mapping", "Property Card", "Contact"]}' title="Contact" type="button"></button>
#  <button class="action-favorite" title="Set as Favorite" type="button"></button>
#  </div>
#  </div>,
#  <div class="infinite-item infinite-clear-fix"></div>]

# %%
#Set up list to hold response info
house_dict = []

# %%
# Loop through x pages of the website with filter of Single House
page_link = 'https://www.century21.com/real-estate/california/LSCA/?sn=5&sk=Y&pt=1&p={}'
for link in [page_link.format(page) for page in range(1,100000)]:
    res = requests.get(link)
    new_soup = BeautifulSoup(res.text, 'html.parser')
    new_results = new_soup.find_all('div', class_='infinite-item')

    # Loop through returned results
    for result in new_results:
        # Error handling
        try:
            # Identify and return listing type
            listing_type = result.find('div', class_="pdp-listing-type").text
            # Identify and return price of House
            price = result.find('a', class_="listing-price").text
            # Identify and return number and street address of House
            street = result.find('div', class_="property-address").text
            # Identify and return city, state, and zip code of House
            city = result.find('div', class_="property-city").text
            zip_code = city.strip().replace("\n", "")
            City_state = zip_code[:-6]
            # Identify and return room number of House
            bed = result.find('div', class_="property-beds").find('strong').text
            # Identify and return bath number of House
            bath = result.find('div', class_="property-baths").find('strong').text
            # Identify and return half-bath number of House. If half-bath does not exist, it will return 0
            try:    
                half_bath = result.find('div', class_="property-half-baths").find('strong').text
            except:
                half_bath = "0"
                pass
            # Identify and return sqft of House
            sqft = result.find('div', class_="property-sqft").find('strong').text
            # Identify coordinate

            latitude = result.get("data-latitude")
            longitude = result.get("data-longitude")

            # Print results only if title, price, and link are available
            if (listing_type and price and street and city and bed and bath and sqft and latitude and longitude):
                house_obj = {
                "Listing_type": listing_type,
                "Price": price.strip().replace("\n", ""),
                "Street": street.strip().replace("\n", ""),
                "City": City_state[:-3],
                "State": City_state[-2:],
                "Zip_code": zip_code[-5:],
                "Bed": bed.strip().replace("\n", ""),
                "Half-bath": half_bath.strip().replace("\n", ""),
                "Bath": bath.strip().replace("\n", ""),
                "Square_Feet": sqft.strip().replace("\n", ""),
                "House_type": "Single Family",
                "Latitude": latitude,
                "Longitude": longitude
                }

                #Continue to add data into collection house_dict
                house_dict.append(house_obj)

        except AttributeError as e:
            continue
            # print(e)

print(house_dict)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\Anaconda3\lib\site-packages\urllib3\connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     379             try:  # Python 2.7, use buffering of HTTP responses
# --> 380                 httplib_response = conn.getresponse(buffering=True)
#     381             except TypeError:  # Python 2.6 and older, Python 3
#
# TypeError: getresponse() got an unexpected keyword argument 'buffering'
#
# During handling of the above exception, another exception occurred:
#
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-4-fc332565e338> in <module>()
#       2 page_link = 'https://www.century21.com/real-estate/california/LSCA/?sn=5&sk=Y&pt=1&p={}'
#       3 for link in [page_link.format(page) for page in range(1,100000)]:
# ----> 4     res = requests.get(link)
#       5     new_soup = BeautifulSoup(res.text, 'html.parser')
#       6     new_results = new_soup.find_all('div', class_='infinite-item')
#
# ~\Anaconda3\lib\site-packages\requests\api.py in get(url, params, **kwargs)
#      70
#      71     kwargs.setdefault('allow_redirects', True)
# ---> 72     return request('get', url, params=params, **kwargs)
#      73
#      74
#
# ~\Anaconda3\lib\site-packages\requests\api.py in request(method, url, **kwargs)
#      56     # cases, and look like a memory leak in others.
#      57     with sessions.Session() as session:
# ---> 58         return session.request(method=method, url=url, **kwargs)
#      59
#      60
#
# ~\Anaconda3\lib\site-packages\requests\sessions.py in request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     506         }
#     507         send_kwargs.update(settings)
# --> 508         resp = self.send(prep, **send_kwargs)
#     509
#     510         return resp
#
# ~\Anaconda3\lib\site-packages\requests\sessions.py in send(self, request, **kwargs)
#     616
#     617         # Send the request
# --> 618         r = adapter.send(request, **kwargs)
#     619
#     620         # Total elapsed time of the request (approximately)
#
# ~\Anaconda3\lib\site-packages\requests\adapters.py in send(self, request, stream, timeout, verify, cert, proxies)
#     438                     decode_content=False,
#     439                     retries=self.max_retries,
# --> 440                     timeout=timeout
#     441                 )
#     442
#
# ~\Anaconda3\lib\site-packages\urllib3\connectionpool.py in urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     599                                                   timeout=timeout_obj,
#     600                                                   body=body, headers=headers,
# --> 601                                                   chunked=chunked)
#     602
#     603             # If we're going to release the connection in ``finally:``, then
#
# ~\Anaconda3\lib\site-packages\urllib3\connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     381             except TypeError:  # Python 2.6 and older, Python 3
#     382                 try:
# --> 383                     httplib_response = conn.getresponse()
#     384                 except Exception as e:
#     385                     # Remove the TypeError from the exception chain in Python 3;
#
# ~\Anaconda3\lib\http\client.py in getresponse(self)
#    1329         try:
#    1330             try:
# -> 1331                 response.begin()
#    1332             except ConnectionError:
#    1333                 self.close()
#
# ~\Anaconda3\lib\http\client.py in begin(self)
#     295         # read until we get a non-100 response
#     296         while True:
# --> 297             version, status, reason = self._read_status()
#     298             if status != CONTINUE:
#     299                 break
#
# ~\Anaconda3\lib\http\client.py in _read_status(self)
#     256
#     257     def _read_status(self):
# --> 258         line = str(self.fp.readline(_MAXLINE + 1), "iso-8859-1")
#     259         if len(line) > _MAXLINE:
#     260             raise LineTooLong("status line")
#
# ~\Anaconda3\lib\socket.py in readinto(self, b)
#     584         while True:
#     585             try:
# --> 586                 return self._sock.recv_into(b)
#     587             except timeout:
#     588                 self._timeout_occurred = True
#
# ~\Anaconda3\lib\site-packages\urllib3\contrib\pyopenssl.py in recv_into(self, *args, **kwargs)
#     278     def recv_into(self, *args, **kwargs):
#     279         try:
# --> 280             return self.connection.recv_into(*args, **kwargs)
#     281         except OpenSSL.SSL.SysCallError as e:
#     282             if self.suppress_ragged_eofs and e.args == (-1, 'Unexpected EOF'):
#
# ~\Anaconda3\lib\site-packages\OpenSSL\SSL.py in recv_into(self, buffer, nbytes, flags)
#    1712             result = _lib.SSL_peek(self._ssl, buf, nbytes)
#    1713         else:
# -> 1714             result = _lib.SSL_read(self._ssl, buf, nbytes)
#    1715         self._raise_ssl_error(self._ssl, result)
#    1716
#
# KeyboardInterrupt:

# %%
house_data = pd.DataFrame(house_dict)
house_data

# %%
# Export file as a CSV, without the Pandas index, but with the header
house_data.to_csv("Output/Q2-2018_Single_Family_Data.csv", index=False, header=True)
